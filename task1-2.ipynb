# %%
from sqlalchemy import create_engine, String, Integer, BigInteger, Column, Float, insert, select, update,delete, func
from sqlalchemy.orm import sessionmaker, declarative_base
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns 
from datetime import datetime
import kaggle 

from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.cluster import KMeans

# %%
# !kaggle datasets download zeesolver/consumer-behavior-and-shopping-habits-dataset -f shopping_trends.csv
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.7.4 / client 1.6.17)
# Dataset URL: https://www.kaggle.com/datasets/zeesolver/consumer-behavior-and-shopping-habits-dataset
# License(s): CC0-1.0
# shopping_trends.csv: Skipping, found more recently modified local copy (use --force to force download)

# %%
username = 'root'
password = '**********'
host = '127.0.0.1'
port = '3306'
database = 'consumer_analysis'
engine = create_engine(f'mysql+pymysql://{username}:{password}@{host}:{port}/{database}', echo = True)

def update_df():
    return pd.read_sql('shopping_trends', con = engine)

df_trend = pd.read_csv('shopping_trends.csv')
df_trend.to_sql('shopping_trends', con = engine, if_exists = 'replace', index = False)

engine.dispose()
# Out:
# 2025-03-14 15:25:40,877 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2025-03-14 15:25:40,877 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-14 15:25:40,877 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2025-03-14 15:25:40,886 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-14 15:25:40,888 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2025-03-14 15:25:40,888 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-14 15:25:40,892 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-14 15:25:40,900 INFO sqlalchemy.engine.Engine DESCRIBE `consumer_analysis`.`shopping_trends`
# 2025-03-14 15:25:40,902 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-14 15:25:40,911 INFO sqlalchemy.engine.Engine DESCRIBE `consumer_analysis`.`shopping_trends`
# 2025-03-14 15:25:40,914 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-14 15:25:40,920 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `consumer_analysis`
# 2025-03-14 15:25:40,921 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-14 15:25:40,925 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `consumer_analysis`
# 2025-03-14 15:25:40,925 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-14 15:25:40,946 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `shopping_trends`
# 2025-03-14 15:25:40,947 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-14 15:25:40,957 INFO sqlalchemy.engine.Engine
# DROP TABLE shopping_trends
# 2025-03-14 15:25:40,959 INFO sqlalchemy.engine.Engine [no key 0.00228s] {}
# 2025-03-14 15:25:41,022 INFO sqlalchemy.engine.Engine
# CREATE TABLE shopping_trends (
# 	`Customer ID` BIGINT,
# 	`Age` BIGINT,
# 	`Gender` TEXT,
# 	`Item Purchased` TEXT,
# 	`Category` TEXT,
# 	`Purchase Amount (USD)` BIGINT,
# 	`Location` TEXT,
# 	`Size` TEXT,
# 	`Color` TEXT,
# 	`Season` TEXT,
# 	`Review Rating` FLOAT(53),
# 	`Subscription Status` TEXT,
# 	`Payment Method` TEXT,
# 	`Shipping Type` TEXT,
# 	`Discount Applied` TEXT,
# 	`Promo Code Used` TEXT,
# 	`Previous Purchases` BIGINT,
# 	`Preferred Payment Method` TEXT,
# 	`Frequency of Purchases` TEXT
# )
#
#
# 2025-03-14 15:25:41,023 INFO sqlalchemy.engine.Engine [no key 0.00124s] {}
# 2025-03-14 15:25:41,153 INFO sqlalchemy.engine.Engine INSERT INTO shopping_trends (`Customer ID`, `Age`, `Gender`, `Item Purchased`, `Category`, `Purchase Amount (USD)`, `Location`, `Size`, `Color`, `Season`, `Review Rating`, `Subscription Status`, `Payment Method`, `Shipping Type`, `Discount Applied`, `Promo Code Used`, `Previous Purchases`, `Preferred Payment Method`, `Frequency of Purchases`) VALUES (%(Customer_ID)s, %(Age)s, %(Gender)s, %(Item_Purchased)s, %(Category)s, %(Purchase_Amount_AUSDZ)s, %(Location)s, %(Size)s, %(Color)s, %(Season)s, %(Review_Rating)s, %(Subscription_Status)s, %(Payment_Method)s, %(Shipping_Type)s, %(Discount_Applied)s, %(Promo_Code_Used)s, %(Previous_Purchases)s, %(Preferred_Payment_Method)s, %(Frequency_of_Purchases)s)
# 2025-03-14 15:25:41,153 INFO sqlalchemy.engine.Engine [generated in 0.06240s] [{'Customer_ID': 1, 'Age': 55, 'Gender': 'Male', 'Item_Purchased': 'Blouse', 'Category': 'Clothing', 'Purchase_Amount_AUSDZ': 53, 'Location': 'Kentucky', 'Size': 'L', 'Color': 'Gray', 'Season': 'Winter', 'Review_Rating': 3.1, 'Subscription_Status': 'Yes', 'Payment_Method': 'Credit Card', 'Shipping_Type': 'Express', 'Discount_Applied': 'Yes', 'Promo_Code_Used': 'Yes', 'Previous_Purchases': 14, 'Preferred_Payment_Method': 'Venmo', 'Frequency_of_Purchases': 'Fortnightly'}, {'Customer_ID': 2, 'Age': 19, 'Gender': 'Male', 'Item_Purchased': 'Sweater', 'Category': 'Clothing', 'Purchase_Amount_AUSDZ': 64, 'Location': 'Maine', 'Size': 'L', 'Color': 'Maroon', 'Season': 'Winter', 'Review_Rating': 3.1, 'Subscription_Status': 'Yes', 'Payment_Method': 'Bank Transfer', 'Shipping_Type': 'Express', 'Discount_Applied': 'Yes', 'Promo_Code_Used': 'Yes', 'Previous_Purchases': 2, 'Preferred_Payment_Method': 'Cash', 'Frequency_of_Purchases': 'Fortnightly'}, {'Customer_ID': 3, 'Age': 50, 'Gender': 'Male', 'Item_Purchased': 'Jeans', 'Category': 'Clothing', 'Purchase_Amount_AUSDZ': 73, 'Location': 'Massachusetts', 'Size': 'S', 'Color': 'Maroon', 'Season': 'Spring', 'Review_Rating': 3.1, 'Subscription_Status': 'Yes', 'Payment_Method': 'Cash', 'Shipping_Type': 'Free Shipping', 'Discount_Applied': 'Yes', 'Promo_Code_Used': 'Yes', 'Previous_Purchases': 23, 'Preferred_Payment_Method': 'Credit Card', 'Frequency_of_Purchases': 'Weekly'}, {'Customer_ID': 4, 'Age': 21, 'Gender': 'Male', 'Item_Purchased': 'Sandals', 'Category': 'Footwear', 'Purchase_Amount_AUSDZ': 90, 'Location': 'Rhode Island', 'Size': 'M', 'Color': 'Maroon', 'Season': 'Spring', 'Review_Rating': 3.5, 'Subscription_Status': 'Yes', 'Payment_Method': 'PayPal', 'Shipping_Type': 'Next Day Air', 'Discount_Applied': 'Yes', 'Promo_Code_Used': 'Yes', 'Previous_Purchases': 49, 'Preferred_Payment_Method': 'PayPal', 'Frequency_of_Purchases': 'Weekly'}, {'Customer_ID': 5, 'Age': 45, 'Gender': 'Male', 'Item_Purchased': 'Blouse', 'Category': 'Clothing', 'Purchase_Amount_AUSDZ': 49, 'Location': 'Oregon', 'Size': 'M', 'Color': 'Turquoise', 'Season': 'Spring', 'Review_Rating': 2.7, 'Subscription_Status': 'Yes', 'Payment_Method': 'Cash', 'Shipping_Type': 'Free Shipping', 'Discount_Applied': 'Yes', 'Promo_Code_Used': 'Yes', 'Previous_Purchases': 31, 'Preferred_Payment_Method': 'PayPal', 'Frequency_of_Purchases': 'Annually'}, {'Customer_ID': 6, 'Age': 46, 'Gender': 'Male', 'Item_Purchased': 'Sneakers', 'Category': 'Footwear', 'Purchase_Amount_AUSDZ': 20, 'Location': 'Wyoming', 'Size': 'M', 'Color': 'White', 'Season': 'Summer', 'Review_Rating': 2.9, 'Subscription_Status': 'Yes', 'Payment_Method': 'Venmo', 'Shipping_Type': 'Standard', 'Discount_Applied': 'Yes', 'Promo_Code_Used': 'Yes', 'Previous_Purchases': 14, 'Preferred_Payment_Method': 'Venmo', 'Frequency_of_Purchases': 'Weekly'}, {'Customer_ID': 7, 'Age': 63, 'Gender': 'Male', 'Item_Purchased': 'Shirt', 'Category': 'Clothing', 'Purchase_Amount_AUSDZ': 85, 'Location': 'Montana', 'Size': 'M', 'Color': 'Gray', 'Season': 'Fall', 'Review_Rating': 3.2, 'Subscription_Status': 'Yes', 'Payment_Method': 'Debit Card', 'Shipping_Type': 'Free Shipping', 'Discount_Applied': 'Yes', 'Promo_Code_Used': 'Yes', 'Previous_Purchases': 49, 'Preferred_Payment_Method': 'Cash', 'Frequency_of_Purchases': 'Quarterly'}, {'Customer_ID': 8, 'Age': 27, 'Gender': 'Male', 'Item_Purchased': 'Shorts', 'Category': 'Clothing', 'Purchase_Amount_AUSDZ': 34, 'Location': 'Louisiana', 'Size': 'L', 'Color': 'Charcoal', 'Season': 'Winter', 'Review_Rating': 3.2, 'Subscription_Status': 'Yes', 'Payment_Method': 'Debit Card', 'Shipping_Type': 'Free Shipping', 'Discount_Applied': 'Yes', 'Promo_Code_Used': 'Yes', 'Previous_Purchases': 19, 'Preferred_Payment_Method': 'Credit Card', 'Frequency_of_Purchases': 'Weekly'}  ... displaying 10 of 3900 total bound parameter sets ...  {'Customer_ID': 3899, 'Age': 44, 'Gender': 'Female', 'Item_Pu ...
# 2025-03-14 15:25:41,481 INFO sqlalchemy.engine.Engine COMMIT

# %%
Session = sessionmaker(bind = engine)
session = Session()

Base = declarative_base()

class ShoppingTrends(Base):
    __tablename__ = 'shopping_trends'  # Name of the table in the database

    customer_id = Column('Customer ID', BigInteger, primary_key=True, autoincrement = True)  # Customer ID
    age = Column('Age', BigInteger)  # Age
    gender = Column('Gender', String(10))  # Gender
    item_purchased = Column('Item Purchased', String(100))  # Item Purchased
    category = Column('Category', String(50))  # Category
    purchase_amount_usd = Column('Purchase Amount (USD)', BigInteger)  # Purchase Amount (USD)
    location = Column('Location', String(100))  # Location
    size = Column('Size', String(10))  # Size
    color = Column('Color', String(20))  # Color
    season = Column('Season', String(20))  # Season
    review_rating = Column('Review Rating', Float)  # Review Rating
    subscription_status = Column('Subscription Status', String(10))  # Subscription Status
    payment_method = Column('Payment Method', String(30))  # Payment Method
    shipping_type = Column('Shipping Type', String(20))  # Shipping Type
    discount_applied = Column('Discount Applied', String(10))  # Discount Applied
    promo_code_used = Column('Promo Code Used', String(10))  # Promo Code Used
    previous_purchases = Column('Previous Purchases', BigInteger)  # Previous Purchases
    preferred_payment_method = Column('Preferred Payment Method', String(20))  # Preferred Payment Method
    frequency_of_purchases = Column('Frequency of Purchases', String(20))  # Frequency of Purchases

    def __repr__(self):
        return (f"<ShoppingTrends(customer_id={self.customer_id}, "
                f"age={self.age}, gender='{self.gender}', "
                f"item_purchased='{self.item_purchased}', category='{self.category}', "
                f"purchase_amount_usd={self.purchase_amount_usd}, location='{self.location}', "
                f"size='{self.size}', color='{self.color}', season='{self.season}', "
                f"review_rating={self.review_rating}, subscription_status='{self.subscription_status}', "
                f"payment_method='{self.payment_method}', shipping_type='{self.shipping_type}', "
                f"discount_applied='{self.discount_applied}', promo_code_used='{self.promo_code_used}', "
                f"previous_purchases={self.previous_purchases}, "
                f"preferred_payment_method='{self.preferred_payment_method}', "
                f"frequency_of_purchases='{self.frequency_of_purchases}')>")

# %%
user = ShoppingTrends(customer_id = 3901,
                      age = 25, 
                      gender = 'Male', 
                      item_purchased = 'Shirt', 
                      category = 'Clothing',
                      purchase_amount_usd = 100,
                      location = 'Oregon', 
                      size = 'L',
                      color = 'White',
                      season = 'Winter',
                      review_rating = 4,
                      subscription_status = 'Yes',
                      payment_method = 'PayPal',
                      shipping_type = 'Free Shipping',
                      discount_applied = 'Yes',
                      promo_code_used = 'Yes',
                      previous_purchases = 5,
                      preferred_payment_method = 'Credit Card',
                      frequency_of_purchases = 'Quarterly'
                     )
#session.add(user)




user2 = ShoppingTrends(customer_id = 3902,
                      age = 55, 
                      gender = 'Male', 
                      item_purchased = 'Shirt', 
                      category = 'Clothing',
                      purchase_amount_usd = 50,
                      location = 'Oregon', 
                      size = 'M',
                      color = 'White',
                      season = 'Summer',
                      review_rating = 2,
                      subscription_status = 'No',
                      payment_method = 'PayPal',
                      shipping_type = 'Free Shipping',
                      discount_applied = 'Yes',
                      promo_code_used = 'Yes',
                      previous_purchases = 5,
                      preferred_payment_method = 'Credit Card',
                      frequency_of_purchases = 'Quarterly'
                     )

user3 = ShoppingTrends(age = 100)

user4 = user2 = ShoppingTrends(
                      age = 40, 
                      item_purchased = 'Shirt', 
                      category = 'Clothing',
                      purchase_amount_usd = 50,
                      location = 'Oregon', 
                      size = 'M',
                      color = 'White',
                      season = 'Summer',
                      review_rating = 2,
                      subscription_status = 'No',
                      payment_method = 'PayPal',
                      shipping_type = 'Free Shipping',
                      discount_applied = 'Yes',
                      promo_code_used = 'Yes',
                      previous_purchases = 5,
                      preferred_payment_method = 'Credit Card',
                      frequency_of_purchases = 'Quarterly'
                     )

session.add_all([user, user2, user3, user4])


try:
    session.commit()
    print('loaded successfully')
except Exception as e:
    session.rollback()
    print(f'error {e}')
# Out:
# 2025-03-14 15:25:41,530 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-14 15:25:41,535 INFO sqlalchemy.engine.Engine INSERT INTO shopping_trends (`Customer ID`, `Age`, `Gender`, `Item Purchased`, `Category`, `Purchase Amount (USD)`, `Location`, `Size`, `Color`, `Season`, `Review Rating`, `Subscription Status`, `Payment Method`, `Shipping Type`, `Discount Applied`, `Promo Code Used`, `Previous Purchases`, `Preferred Payment Method`, `Frequency of Purchases`) VALUES (%(Customer_ID)s, %(Age)s, %(Gender)s, %(Item_Purchased)s, %(Category)s, %(Purchase_Amount_AUSDZ)s, %(Location)s, %(Size)s, %(Color)s, %(Season)s, %(Review_Rating)s, %(Subscription_Status)s, %(Payment_Method)s, %(Shipping_Type)s, %(Discount_Applied)s, %(Promo_Code_Used)s, %(Previous_Purchases)s, %(Preferred_Payment_Method)s, %(Frequency_of_Purchases)s)
# 2025-03-14 15:25:41,537 INFO sqlalchemy.engine.Engine [generated in 0.00137s] {'Customer_ID': 3901, 'Age': 25, 'Gender': 'Male', 'Item_Purchased': 'Shirt', 'Category': 'Clothing', 'Purchase_Amount_AUSDZ': 100, 'Location': 'Oregon', 'Size': 'L', 'Color': 'White', 'Season': 'Winter', 'Review_Rating': 4, 'Subscription_Status': 'Yes', 'Payment_Method': 'PayPal', 'Shipping_Type': 'Free Shipping', 'Discount_Applied': 'Yes', 'Promo_Code_Used': 'Yes', 'Previous_Purchases': 5, 'Preferred_Payment_Method': 'Credit Card', 'Frequency_of_Purchases': 'Quarterly'}
# 2025-03-14 15:25:41,542 INFO sqlalchemy.engine.Engine INSERT INTO shopping_trends (`Age`, `Gender`, `Item Purchased`, `Category`, `Purchase Amount (USD)`, `Location`, `Size`, `Color`, `Season`, `Review Rating`, `Subscription Status`, `Payment Method`, `Shipping Type`, `Discount Applied`, `Promo Code Used`, `Previous Purchases`, `Preferred Payment Method`, `Frequency of Purchases`) VALUES (%(Age)s, %(Gender)s, %(Item_Purchased)s, %(Category)s, %(Purchase_Amount_AUSDZ)s, %(Location)s, %(Size)s, %(Color)s, %(Season)s, %(Review_Rating)s, %(Subscription_Status)s, %(Payment_Method)s, %(Shipping_Type)s, %(Discount_Applied)s, %(Promo_Code_Used)s, %(Previous_Purchases)s, %(Preferred_Payment_Method)s, %(Frequency_of_Purchases)s)
# 2025-03-14 15:25:41,542 INFO sqlalchemy.engine.Engine [generated in 0.00140s] {'Age': 40, 'Gender': None, 'Item_Purchased': 'Shirt', 'Category': 'Clothing', 'Purchase_Amount_AUSDZ': 50, 'Location': 'Oregon', 'Size': 'M', 'Color': 'White', 'Season': 'Summer', 'Review_Rating': 2, 'Subscription_Status': 'No', 'Payment_Method': 'PayPal', 'Shipping_Type': 'Free Shipping', 'Discount_Applied': 'Yes', 'Promo_Code_Used': 'Yes', 'Previous_Purchases': 5, 'Preferred_Payment_Method': 'Credit Card', 'Frequency_of_Purchases': 'Quarterly'}
# 2025-03-14 15:25:41,546 INFO sqlalchemy.engine.Engine INSERT INTO shopping_trends (`Age`, `Gender`, `Item Purchased`, `Category`, `Purchase Amount (USD)`, `Location`, `Size`, `Color`, `Season`, `Review Rating`, `Subscription Status`, `Payment Method`, `Shipping Type`, `Discount Applied`, `Promo Code Used`, `Previous Purchases`, `Preferred Payment Method`, `Frequency of Purchases`) VALUES (%(Age)s, %(Gender)s, %(Item_Purchased)s, %(Category)s, %(Purchase_Amount_AUSDZ)s, %(Location)s, %(Size)s, %(Color)s, %(Season)s, %(Review_Rating)s, %(Subscription_Status)s, %(Payment_Method)s, %(Shipping_Type)s, %(Discount_Applied)s, %(Promo_Code_Used)s, %(Previous_Purchases)s, %(Preferred_Payment_Method)s, %(Frequency_of_Purchases)s)
# 2025-03-14 15:25:41,548 INFO sqlalchemy.engine.Engine [cached since 0.005622s ago] {'Age': 100, 'Gender': None, 'Item_Purchased': None, 'Category': None, 'Purchase_Amount_AUSDZ': None, 'Location': None, 'Size': None, 'Color': None, 'Season': None, 'Review_Rating': None, 'Subscription_Status': None, 'Payment_Method': None, 'Shipping_Type': None, 'Discount_Applied': None, 'Promo_Code_Used': None, 'Previous_Purchases': None, 'Preferred_Payment_Method': None, 'Frequency_of_Purchases': None}
# 2025-03-14 15:25:41,551 INFO sqlalchemy.engine.Engine COMMIT
# loaded successfully
# C:\Users\hosin\AppData\Local\Temp\ipykernel_13216\4206271437.py:73: SAWarning: Identity map already had an identity for (<class '__main__.ShoppingTrends'>, (0,), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()

# %%
#modify 
null_ages = session.query(ShoppingTrends).filter(ShoppingTrends.customer_id.is_(None)).all()

if null_ages:
    for row in null_ages:
        print(row)  # Print the whole row
else:
    print("No rows found with NULL customer_id.")
# Out:
# 2025-03-14 15:25:41,565 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-14 15:25:41,571 INFO sqlalchemy.engine.Engine SELECT shopping_trends.`Customer ID` AS `shopping_trends_Customer ID`, shopping_trends.`Age` AS `shopping_trends_Age`, shopping_trends.`Gender` AS `shopping_trends_Gender`, shopping_trends.`Item Purchased` AS `shopping_trends_Item Purchased`, shopping_trends.`Category` AS `shopping_trends_Category`, shopping_trends.`Purchase Amount (USD)` AS `shopping_trends_Purchase Amount (USD)`, shopping_trends.`Location` AS `shopping_trends_Location`, shopping_trends.`Size` AS `shopping_trends_Size`, shopping_trends.`Color` AS `shopping_trends_Color`, shopping_trends.`Season` AS `shopping_trends_Season`, shopping_trends.`Review Rating` AS `shopping_trends_Review Rating`, shopping_trends.`Subscription Status` AS `shopping_trends_Subscription Status`, shopping_trends.`Payment Method` AS `shopping_trends_Payment Method`, shopping_trends.`Shipping Type` AS `shopping_trends_Shipping Type`, shopping_trends.`Discount Applied` AS `shopping_trends_Discount Applied`, shopping_trends.`Promo Code Used` AS `shopping_trends_Promo Code Used`, shopping_trends.`Previous Purchases` AS `shopping_trends_Previous Purchases`, shopping_trends.`Preferred Payment Method` AS `shopping_trends_Preferred Payment Method`, shopping_trends.`Frequency of Purchases` AS `shopping_trends_Frequency of Purchases`
# FROM shopping_trends
# WHERE shopping_trends.`Customer ID` IS NULL
# 2025-03-14 15:25:41,572 INFO sqlalchemy.engine.Engine [generated in 0.00138s] {}
# None

# %%
# query customer_id where it is None
a = session.query(ShoppingTrends.customer_id).filter(ShoppingTrends.customer_id.is_(None))
# Print the query object
print(a)

# To actually execute the query and get results, use all() or similar method
results = a.all()
print(results)

# Update all NULL customer_id values to a specific value, e.g., 1
session.query(ShoppingTrends).filter(ShoppingTrends.customer_id.is_(None)).update({'customer_id': 0})

# Commit the changes to the database
session.commit()
print("Updated all NULL Customer IDs .")
# Out:
# SELECT shopping_trends.`Customer ID` AS `shopping_trends_Customer ID`
# FROM shopping_trends
# WHERE shopping_trends.`Customer ID` IS NULL
# 2025-03-14 15:25:41,600 INFO sqlalchemy.engine.Engine SELECT shopping_trends.`Customer ID` AS `shopping_trends_Customer ID`
# FROM shopping_trends
# WHERE shopping_trends.`Customer ID` IS NULL
# 2025-03-14 15:25:41,601 INFO sqlalchemy.engine.Engine [generated in 0.00130s] {}
# [(None,), (None,)]
# 2025-03-14 15:25:41,612 INFO sqlalchemy.engine.Engine UPDATE shopping_trends SET `Customer ID`=%(Customer_ID)s WHERE shopping_trends.`Customer ID` IS NULL
# 2025-03-14 15:25:41,612 INFO sqlalchemy.engine.Engine [generated in 0.00120s] {'Customer_ID': 0}
# 2025-03-14 15:25:41,627 INFO sqlalchemy.engine.Engine COMMIT
# Updated all NULL Customer IDs .

# %%
# Correct way to query customer_id where it is None
a = session.query(ShoppingTrends.customer_id).filter(ShoppingTrends.customer_id.is_(None))
# Print the query object
print(a)

# To actually execute the query and get results, use all() or similar method
results = a.all()
print(results)

# Update all NULL customer_id values to a specific value, e.g., 0
# == df['Customer ID']=df['Customer ID'].fillna(0)
session.query(ShoppingTrends).filter(ShoppingTrends.customer_id.is_(None)).update({'customer_id':0}) #update() can only update a single value 

# Commit the changes to the database
session.commit()
print("Updated all NULL Customer IDs .")
# Out:
# SELECT shopping_trends.`Customer ID` AS `shopping_trends_Customer ID`
# FROM shopping_trends
# WHERE shopping_trends.`Customer ID` IS NULL
# 2025-03-14 15:25:41,645 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-14 15:25:41,645 INFO sqlalchemy.engine.Engine SELECT shopping_trends.`Customer ID` AS `shopping_trends_Customer ID`
# FROM shopping_trends
# WHERE shopping_trends.`Customer ID` IS NULL
# 2025-03-14 15:25:41,645 INFO sqlalchemy.engine.Engine [cached since 0.04772s ago] {}
# []
# 2025-03-14 15:25:41,655 INFO sqlalchemy.engine.Engine UPDATE shopping_trends SET `Customer ID`=%(Customer_ID)s WHERE shopping_trends.`Customer ID` IS NULL
# 2025-03-14 15:25:41,656 INFO sqlalchemy.engine.Engine [cached since 0.04338s ago] {'Customer_ID': 0}
# 2025-03-14 15:25:41,674 INFO sqlalchemy.engine.Engine COMMIT
# Updated all NULL Customer IDs .

# %%
#select customer_id from shooping_trends where age >= 40
#select count(*) from shooping_trends where age >= 40
# Correct way to query for the first record where age is 40
a = session.query(ShoppingTrends).filter(ShoppingTrends.age >= 40).all()
cnt = session.query(ShoppingTrends).filter(ShoppingTrends.age >= 40).count()
for row in a:
    print(row.customer_id)
print(cnt)
# Out:
# 2025-03-14 15:25:41,695 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-14 15:25:41,697 INFO sqlalchemy.engine.Engine SELECT shopping_trends.`Customer ID` AS `shopping_trends_Customer ID`, shopping_trends.`Age` AS `shopping_trends_Age`, shopping_trends.`Gender` AS `shopping_trends_Gender`, shopping_trends.`Item Purchased` AS `shopping_trends_Item Purchased`, shopping_trends.`Category` AS `shopping_trends_Category`, shopping_trends.`Purchase Amount (USD)` AS `shopping_trends_Purchase Amount (USD)`, shopping_trends.`Location` AS `shopping_trends_Location`, shopping_trends.`Size` AS `shopping_trends_Size`, shopping_trends.`Color` AS `shopping_trends_Color`, shopping_trends.`Season` AS `shopping_trends_Season`, shopping_trends.`Review Rating` AS `shopping_trends_Review Rating`, shopping_trends.`Subscription Status` AS `shopping_trends_Subscription Status`, shopping_trends.`Payment Method` AS `shopping_trends_Payment Method`, shopping_trends.`Shipping Type` AS `shopping_trends_Shipping Type`, shopping_trends.`Discount Applied` AS `shopping_trends_Discount Applied`, shopping_trends.`Promo Code Used` AS `shopping_trends_Promo Code Used`, shopping_trends.`Previous Purchases` AS `shopping_trends_Previous Purchases`, shopping_trends.`Preferred Payment Method` AS `shopping_trends_Preferred Payment Method`, shopping_trends.`Frequency of Purchases` AS `shopping_trends_Frequency of Purchases`
# FROM shopping_trends
# WHERE shopping_trends.`Age` >= %(Age_1)s
# 2025-03-14 15:25:41,699 INFO sqlalchemy.engine.Engine [generated in 0.00164s] {'Age_1': 40}
# 2025-03-14 15:25:41,845 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM (SELECT shopping_trends.`Customer ID` AS `shopping_trends_Customer ID`, shopping_trends.`Age` AS `shopping_trends_Age`, shopping_trends.`Gender` AS `shopping_trends_Gender`, shopping_trends.`Item Purchased` AS `shopping_trends_Item Purchased`, shopping_trends.`Category` AS `shopping_trends_Category`, shopping_trends.`Purchase Amount (USD)` AS `shopping_trends_Purchase Amount (USD)`, shopping_trends.`Location` AS `shopping_trends_Location`, shopping_trends.`Size` AS `shopping_trends_Size`, shopping_trends.`Color` AS `shopping_trends_Color`, shopping_trends.`Season` AS `shopping_trends_Season`, shopping_trends.`Review Rating` AS `shopping_trends_Review Rating`, shopping_trends.`Subscription Status` AS `shopping_trends_Subscription Status`, shopping_trends.`Payment Method` AS `shopping_trends_Payment Method`, shopping_trends.`Shipping Type` AS `shopping_trends_Shipping Type`, shopping_trends.`Discount Applied` AS `shopping_trends_Discount Applied`, shopping_trends.`Promo Code Used` AS `shopping_trends_Promo Code Used`, shopping_trends.`Previous Purchases` AS `shopping_trends_Previous Purchases`, shopping_trends.`Preferred Payment Method` AS `shopping_trends_Preferred Payment Method`, shopping_trends.`Frequency of Purchases` AS `shopping_trends_Frequency of Purchases`
# FROM shopping_trends
# WHERE shopping_trends.`Age` >= %(Age_1)s) AS anon_1
# 2025-03-14 15:25:41,846 INFO sqlalchemy.engine.Engine [generated in 0.00103s] {'Age_1': 40}
# 1
# 3
# 5
# 6
# 7
# 10
# 11
# 13
# 14
# 15
# 16
# 18
# 19
# 20
# 23
# 28
# 29
# 31
# 34
# 36
# 40
# 41
# 42
# 46
# 47
# 48
# 49
# 50
# 51
# 52
# 53
# 55
# 56
# 57
# 59
# 60
# 61
# 62
# 65
# 66
# 68
# 69
# 70
# 74
# 75
# 76
# 77
# 79
# 82
# 85
# 86
# 88
# 90
# 92
# 93
# 95
# 101
# 103
# 104
# 105
# 106
# 107
# 109
# 110
# 111
# 114
# 115
# 116
# 117
# 118
# 119
# 121
# 123
# 124
# 125
# 126
# 127
# 131
# 134
# 135
# 136
# 138
# 139
# 140
# 141
# 142
# 147
# 148
# 154
# 155
# 156
# 160
# 162
# 163
# 164
# 165
# 166
# 167
# 171
# 173
# 175
# 176
# 177
# 179
# 180
# 181
# 184
# 186
# 189
# 191
# 192
# 193
# 195
# 196
# 198
# 199
# 200
# 202
# 203
# 204
# 206
# 208
# 209
# 210
# 211
# 212
# 213
# 216
# 217
# 223
# 225
# 228
# 230
# 231
# 233
# 236
# 238
# 239
# 240
# 241
# 243
# 245
# 246
# 249
# 250
# 254
# 255
# 256
# 257
# 259
# 267
# 268
# 269
# 270
# 272
# 273
# 274
# 275
# 276
# 279
# 281
# 285
# 288
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 298
# 299
# 302
# 305
# 306
# 309
# 310
# 311
# 312
# 314
# 316
# 318
# 319
# 320
# 321
# 322
# 323
# 324
# 326
# 327
# 328
# 329
# 330
# 331
# 335
# 339
# 340
# 341
# 343
# 346
# 347
# 349
# 351
# 354
# 355
# 357
# 359
# 361
# 362
# 363
# 364
# 365
# 366
# 367
# 368
# 371
# 375
# 376
# 377
# 378
# 379
# 382
# 384
# 385
# 386
# 387
# 388
# 395
# 397
# 400
# 402
# 406
# 407
# 408
# 412
# 414
# 416
# 420
# 423
# 424
# 425
# 426
# 427
# 428
# 430
# 432
# 433
# 434
# 435
# 436
# 437
# 438
# 439
# 440
# 442
# 445
# 446
# 448
# 452
# 453
# 454
# 456
# 457
# 459
# 460
# 461
# 463
# 466
# 471
# 472
# 475
# 478
# 481
# 482
# 483
# 485
# 486
# 488
# 489
# 490
# 491
# 492
# 493
# 498
# 499
# 502
# 503
# 504
# 505
# 506
# 508
# 510
# 512
# 515
# 518
# 521
# 523
# 524
# 525
# 526
# 527
# 531
# 532
# 534
# 535
# 536
# 537
# 538
# 540
# 541
# 542
# 544
# 547
# 551
# 554
# 555
# 556
# 557
# 559
# 560
# 562
# 563
# 564
# 565
# 566
# 567
# 569
# 570
# 571
# 572
# 573
# 574
# 575
# 576
# 577
# 579
# 580
# 581
# 583
# 585
# 586
# 587
# 589
# 591
# 592
# 593
# 594
# 598
# 600
# 605
# 606
# 608
# 609
# 610
# 611
# 612
# 613
# 614
# 615
# 616
# 618
# 619
# 622
# 623
# 625
# 626
# 628
# 629
# 631
# 632
# 634
# 637
# 639
# 640
# 641
# 642
# 643
# 645
# 646
# 647
# 648
# 650
# 653
# 657
# 658
# 659
# 660
# 661
# 662
# 664
# 665
# 666
# 669
# 670
# 671
# 673
# 675
# 676
# 678
# 680
# 681
# 685
# 686
# 687
# 692
# 694
# 695
# 697
# 698
# 699
# 700
# 701
# 702
# 704
# 707
# 708
# 710
# 712
# 713
# 720
# 722
# 726
# 728
# 730
# 731
# 732
# 734
# 735
# 736
# 738
# 739
# 740
# 743
# 745
# 746
# 747
# 748
# 750
# 752
# 754
# 756
# 757
# 758
# 759
# 760
# 762
# 763
# 764
# 765
# 766
# 767
# 769
# 770
# 775
# 776
# 777
# 778
# 780
# 784
# 786
# 787
# 788
# 789
# 792
# 795
# 797
# 798
# 800
# 805
# 806
# 807
# 809
# 810
# 811
# 813
# 814
# 819
# 820
# 821
# 822
# 824
# 825
# 827
# 830
# 831
# 832
# 833
# 834
# 835
# 840
# 841
# 842
# 843
# 844
# 845
# 847
# 848
# 849
# 851
# 854
# 856
# 857
# 858
# 860
# 862
# 864
# 865
# 866
# 867
# 869
# 871
# 872
# 873
# 874
# 877
# 878
# 880
# 882
# 883
# 885
# 886
# 888
# 889
# 890
# 891
# 895
# 896
# 897
# 899
# 900
# 901
# 902
# 903
# 904
# 905
# 906
# 907
# 910
# 911
# 912
# 915
# 917
# 918
# 919
# 920
# 922
# 923
# 924
# 925
# 927
# 929
# 930
# 933
# 934
# 935
# 936
# 941
# 945
# 947
# 948
# 949
# 951
# 952
# 954
# 955
# 956
# 959
# 962
# 965
# 966
# 967
# 969
# 970
# 971
# 972
# 973
# 974
# 975
# 976
# 979
# 980
# 981
# 987
# 988
# 989
# 990
# 991
# 993
# 994
# 995
# 996
# 998
# 999
# 1000
# 1001
# 1002
# 1003
# 1004
# 1006
# 1008
# 1009
# 1011
# 1012
# 1014
# 1016
# 1019
# 1022
# 1023
# 1024
# 1026
# 1027
# 1029
# 1031
# 1033
# 1035
# 1036
# 1037
# 1038
# 1039
# 1041
# 1043
# 1046
# 1047
# 1050
# 1051
# 1052
# 1053
# 1054
# 1056
# 1058
# 1063
# 1064
# 1066
# 1067
# 1069
# 1071
# 1072
# 1073
# 1075
# 1076
# 1078
# 1081
# 1082
# 1083
# 1087
# 1088
# 1089
# 1090
# 1092
# 1093
# 1094
# 1097
# 1098
# 1099
# 1101
# 1103
# 1107
# 1108
# 1110
# 1113
# 1115
# 1117
# 1119
# 1122
# 1123
# 1125
# 1128
# 1129
# 1131
# 1132
# 1133
# 1135
# 1136
# 1138
# 1140
# 1143
# 1144
# 1145
# 1147
# 1148
# 1152
# 1153
# 1155
# 1156
# 1159
# 1160
# 1162
# 1163
# 1165
# 1166
# 1167
# 1168
# 1169
# 1171
# 1172
# 1173
# 1174
# 1175
# 1178
# 1182
# 1185
# 1186
# 1187
# 1188
# 1189
# 1190
# 1191
# 1193
# 1194
# 1195
# 1198
# 1199
# 1200
# 1203
# 1204
# 1205
# 1206
# 1208
# 1210
# 1214
# 1216
# 1217
# 1218
# 1219
# 1221
# 1223
# 1224
# 1225
# 1227
# 1229
# 1232
# 1233
# 1234
# 1237
# 1239
# 1240
# 1241
# 1242
# 1243
# 1245
# 1246
# 1248
# 1249
# 1250
# 1251
# 1252
# 1255
# 1257
# 1258
# 1259
# 1260
# 1261
# 1264
# 1265
# 1268
# 1270
# 1271
# 1272
# 1274
# 1275
# 1276
# 1277
# 1280
# 1284
# 1285
# 1286
# 1287
# 1289
# 1291
# 1292
# 1297
# 1298
# 1301
# 1302
# 1305
# 1307
# 1309
# 1311
# 1313
# 1314
# 1315
# 1316
# 1319
# 1320
# 1321
# 1322
# 1324
# 1327
# 1328
# 1330
# 1333
# 1335
# 1336
# 1339
# 1341
# 1343
# 1344
# 1345
# 1346
# 1347
# 1348
# 1353
# 1355
# 1356
# 1357
# 1361
# 1362
# 1363
# 1365
# 1367
# 1368
# 1372
# 1373
# 1376
# 1377
# 1381
# 1383
# 1385
# 1386
# 1387
# 1389
# 1390
# 1392
# 1394
# 1396
# 1398
# 1403
# 1408
# 1409
# 1411
# 1412
# 1414
# 1416
# 1417
# 1418
# 1420
# 1422
# 1423
# 1424
# 1425
# 1426
# 1427
# 1431
# 1434
# 1435
# 1436
# 1438
# 1439
# 1443
# 1444
# 1446
# 1447
# 1449
# 1452
# 1453
# 1455
# 1456
# 1457
# 1458
# 1461
# 1462
# 1464
# 1466
# 1467
# 1469
# 1471
# 1474
# 1476
# 1480
# 1482
# 1485
# 1488
# 1491
# 1493
# 1494
# 1495
# 1496
# 1497
# 1498
# 1499
# 1501
# 1504
# 1505
# 1506
# 1508
# 1511
# 1513
# 1518
# 1519
# 1520
# 1524
# 1527
# 1529
# 1531
# 1532
# 1533
# 1534
# 1535
# 1538
# 1539
# 1543
# 1544
# 1546
# 1547
# 1548
# 1549
# 1551
# 1552
# 1553
# 1555
# 1556
# 1557
# 1560
# 1561
# 1562
# 1564
# 1566
# 1567
# 1569
# 1576
# 1577
# 1578
# 1579
# 1581
# 1582
# 1585
# 1588
# 1589
# 1590
# 1591
# 1593
# 1594
# 1595
# 1597
# 1598
# 1599
# 1600
# 1602
# 1603
# 1606
# 1607
# 1608
# 1612
# 1616
# 1618
# 1619
# 1620
# 1622
# 1624
# 1628
# 1629
# 1631
# 1632
# 1634
# 1636
# 1637
# 1639
# 1640
# 1641
# 1642
# 1645
# 1646
# 1647
# 1650
# 1651
# 1652
# 1653
# 1655
# 1658
# 1660
# 1661
# 1662
# 1663
# 1664
# 1666
# 1667
# 1668
# 1669
# 1670
# 1678
# 1679
# 1680
# 1681
# 1683
# 1688
# 1691
# 1692
# 1693
# 1694
# 1696
# 1701
# 1702
# 1703
# 1705
# 1710
# 1713
# 1714
# 1717
# 1719
# 1720
# 1723
# 1724
# 1725
# 1726
# 1727
# 1728
# 1730
# 1733
# 1734
# 1736
# 1737
# 1738
# 1739
# 1741
# 1742
# 1743
# 1745
# 1746
# 1747
# 1748
# 1750
# 1752
# 1755
# 1756
# 1757
# 1760
# 1765
# 1766
# 1767
# 1768
# 1771
# 1772
# 1773
# 1775
# 1777
# 1779
# 1781
# 1783
# 1784
# 1786
# 1787
# 1789
# 1790
# 1791
# 1792
# 1794
# 1795
# 1796
# 1797
# 1798
# 1799
# 1803
# 1804
# 1806
# 1807
# 1809
# 1810
# 1811
# 1812
# 1813
# 1814
# 1816
# 1819
# 1820
# 1822
# 1823
# 1824
# 1825
# 1827
# 1831
# 1832
# 1833
# 1835
# 1836
# 1837
# 1838
# 1841
# 1843
# 1845
# 1846
# 1847
# 1848
# 1851
# 1853
# 1856
# 1857
# 1858
# 1860
# 1863
# 1866
# 1868
# 1871
# 1872
# 1873
# 1874
# 1875
# 1876
# 1877
# 1878
# 1880
# 1882
# 1883
# 1888
# 1889
# 1890
# 1892
# 1895
# 1897
# 1898
# 1899
# 1901
# 1902
# 1904
# 1906
# 1908
# 1910
# 1912
# 1914
# 1916
# 1921
# 1922
# 1924
# 1926
# 1927
# 1928
# 1930
# 1931
# 1932
# 1933
# 1934
# 1937
# 1938
# 1939
# 1940
# 1941
# 1942
# 1943
# 1947
# 1948
# 1949
# 1950
# 1951
# 1953
# 1956
# 1957
# 1958
# 1960
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1969
# 1970
# 1972
# 1973
# 1976
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1987
# 1988
# 1989
# 1992
# 1996
# 1997
# 1998
# 2002
# 2004
# 2005
# 2007
# 2009
# 2012
# 2013
# 2015
# 2016
# 2017
# 2018
# 2019
# 2021
# 2022
# 2023
# 2024
# 2025
# 2026
# 2028
# 2031
# 2033
# 2034
# 2035
# 2036
# 2039
# 2041
# 2042
# 2044
# 2045
# 2048
# 2049
# 2050
# 2052
# 2053
# 2055
# 2057
# 2058
# 2060
# 2063
# 2064
# 2067
# 2068
# 2069
# 2071
# 2072
# 2076
# 2077
# 2078
# 2079
# 2083
# 2084
# 2086
# 2087
# 2088
# 2091
# 2093
# 2095
# 2099
# 2101
# 2102
# 2105
# 2106
# 2107
# 2108
# 2109
# 2110
# 2111
# 2112
# 2113
# 2114
# 2116
# 2117
# 2119
# 2120
# 2121
# 2122
# 2124
# 2125
# 2126
# 2127
# 2128
# 2129
# 2130
# 2135
# 2137
# 2139
# 2140
# 2141
# 2143
# 2144
# 2145
# 2147
# 2148
# 2151
# 2152
# 2155
# 2158
# 2161
# 2163
# 2164
# 2165
# 2171
# 2175
# 2176
# 2180
# 2181
# 2183
# 2186
# 2187
# 2189
# 2191
# 2193
# 2195
# 2196
# 2199
# 2201
# 2203
# 2204
# 2206
# 2207
# 2208
# 2210
# 2212
# 2213
# 2214
# 2215
# 2217
# 2219
# 2228
# 2229
# 2230
# 2231
# 2233
# 2236
# 2238
# 2239
# 2240
# 2241
# 2244
# 2246
# 2247
# 2249
# 2250
# 2251
# 2253
# 2254
# 2256
# 2258
# 2260
# 2262
# 2263
# 2264
# 2265
# 2269
# 2270
# 2274
# 2275
# 2279
# 2280
# 2284
# 2287
# 2288
# 2290
# 2293
# 2295
# 2296
# 2297
# 2298
# 2299
# 2300
# 2304
# 2306
# 2309
# 2310
# 2314
# 2315
# 2316
# 2318
# 2319
# 2320
# 2322
# 2325
# 2326
# 2327
# 2329
# 2330
# 2331
# 2332
# 2335
# 2339
# 2341
# 2342
# 2344
# 2349
# 2350
# 2351
# 2353
# 2354
# 2355
# 2357
# 2358
# 2359
# 2361
# 2362
# 2364
# 2365
# 2366
# 2368
# 2371
# 2372
# 2373
# 2375
# 2376
# 2378
# 2380
# 2381
# 2382
# 2384
# 2386
# 2391
# 2392
# 2393
# 2394
# 2395
# 2396
# 2399
# 2400
# 2401
# 2402
# 2403
# 2404
# 2406
# 2407
# 2408
# 2411
# 2412
# 2413
# 2414
# 2417
# 2421
# 2424
# 2425
# 2426
# 2427
# 2429
# 2430
# 2433
# 2434
# 2437
# 2438
# 2440
# 2442
# 2443
# 2445
# 2446
# 2448
# 2449
# 2451
# 2452
# 2453
# 2457
# 2458
# 2459
# 2460
# 2461
# 2463
# 2464
# 2465
# 2469
# 2470
# 2471
# 2474
# 2476
# 2477
# 2481
# 2482
# 2483
# 2485
# 2486
# 2487
# 2488
# 2489
# 2490
# 2491
# 2492
# 2493
# 2495
# 2496
# 2497
# 2500
# 2501
# 2502
# 2503
# 2504
# 2505
# 2507
# 2508
# 2511
# 2512
# 2513
# 2514
# 2515
# 2517
# 2518
# 2520
# 2521
# 2524
# 2525
# 2527
# 2529
# 2532
# 2533
# 2534
# 2535
# 2536
# 2537
# 2538
# 2543
# 2545
# 2547
# 2548
# 2549
# 2550
# 2551
# 2553
# 2554
# 2555
# 2558
# 2559
# 2560
# 2561
# 2563
# 2564
# 2565
# 2569
# 2570
# 2572
# 2573
# 2574
# 2576
# 2578
# 2579
# 2580
# 2581
# 2582
# 2584
# 2586
# 2588
# 2589
# 2590
# 2591
# 2592
# 2595
# 2597
# 2598
# 2599
# 2600
# 2602
# 2603
# 2604
# 2605
# 2606
# 2607
# 2608
# 2609
# 2610
# 2611
# 2613
# 2614
# 2616
# 2617
# 2619
# 2620
# 2622
# 2623
# 2624
# 2627
# 2628
# 2630
# 2632
# 2634
# 2636
# 2637
# 2644
# 2648
# 2649
# 2652
# 2654
# 2657
# 2658
# 2659
# 2662
# 2664
# 2666
# 2667
# 2668
# 2669
# 2673
# 2674
# 2675
# 2677
# 2678
# 2680
# 2681
# 2683
# 2684
# 2685
# 2686
# 2687
# 2688
# 2689
# 2691
# 2692
# 2693
# 2694
# 2695
# 2696
# 2697
# 2698
# 2699
# 2702
# 2703
# 2704
# 2705
# 2706
# 2709
# 2711
# 2715
# 2717
# 2720
# 2721
# 2724
# 2725
# 2726
# 2728
# 2732
# 2735
# 2736
# 2737
# 2738
# 2739
# 2742
# 2744
# 2750
# 2751
# 2753
# 2754
# 2755
# 2756
# 2757
# 2760
# 2761
# 2763
# 2765
# 2766
# 2767
# 2769
# 2771
# 2772
# 2775
# 2777
# 2778
# 2779
# 2780
# 2782
# 2783
# 2786
# 2787
# 2789
# 2792
# 2793
# 2797
# 2798
# 2799
# 2801
# 2802
# 2804
# 2805
# 2807
# 2808
# 2809
# 2810
# 2812
# 2813
# 2814
# 2817
# 2819
# 2820
# 2823
# 2826
# 2830
# 2831
# 2834
# 2837
# 2838
# 2839
# 2840
# 2841
# 2844
# 2847
# 2848
# 2850
# 2851
# 2852
# 2853
# 2857
# 2858
# 2862
# 2863
# 2865
# 2867
# 2869
# 2870
# 2871
# 2872
# 2873
# 2874
# 2877
# 2879
# 2880
# 2883
# 2885
# 2887
# 2889
# 2890
# 2892
# 2894
# 2896
# 2898
# 2900
# 2901
# 2902
# 2905
# 2906
# 2907
# 2909
# 2913
# 2914
# 2915
# 2917
# 2918
# 2920
# 2923
# 2925
# 2926
# 2927
# 2928
# 2929
# 2933
# 2936
# 2941
# 2943
# 2945
# 2948
# 2949
# 2952
# 2953
# 2954
# 2956
# 2957
# 2958
# 2959
# 2961
# 2963
# 2964
# 2965
# 2966
# 2967
# 2975
# 2976
# 2979
# 2981
# 2984
# 2985
# 2986
# 2987
# 2988
# 2989
# 2990
# 2991
# 2992
# 2993
# 2995
# 2997
# 2998
# 3001
# 3003
# 3004
# 3005
# 3010
# 3011
# 3013
# 3014
# 3018
# 3019
# 3022
# 3023
# 3024
# 3025
# 3026
# 3027
# 3028
# 3029
# 3030
# 3031
# 3032
# 3035
# 3036
# 3037
# 3038
# 3039
# 3040
# 3042
# 3043
# 3044
# 3046
# 3047
# 3049
# 3050
# 3052
# 3053
# 3055
# 3057
# 3058
# 3059
# 3060
# 3061
# 3063
# 3066
# 3067
# 3068
# 3070
# 3071
# 3074
# 3076
# 3077
# 3078
# 3080
# 3081
# 3082
# 3083
# 3085
# 3087
# 3088
# 3090
# 3092
# 3093
# 3096
# 3097
# 3098
# 3099
# 3100
# 3101
# 3103
# 3105
# 3106
# 3107
# 3108
# 3109
# 3110
# 3114
# 3117
# 3118
# 3119
# 3120
# 3121
# 3122
# 3124
# 3125
# 3127
# 3128
# 3129
# 3130
# 3131
# 3134
# 3136
# 3137
# 3139
# 3144
# 3146
# 3148
# 3151
# 3152
# 3153
# 3154
# 3160
# 3162
# 3163
# 3164
# 3165
# 3166
# 3171
# 3172
# 3173
# 3174
# 3175
# 3178
# 3179
# 3180
# 3183
# 3184
# 3185
# 3186
# 3188
# 3189
# 3191
# 3192
# 3194
# 3195
# 3196
# 3199
# 3200
# 3201
# 3202
# 3203
# 3204
# 3205
# 3206
# 3208
# 3209
# 3210
# 3212
# 3215
# 3218
# 3220
# 3223
# 3224
# 3226
# 3227
# 3230
# 3231
# 3232
# 3233
# 3234
# 3235
# 3237
# 3238
# 3241
# 3242
# 3243
# 3244
# 3245
# 3246
# 3247
# 3248
# 3253
# 3256
# 3257
# 3258
# 3260
# 3262
# 3263
# 3264
# 3266
# 3267
# 3271
# 3273
# 3274
# 3275
# 3276
# 3278
# 3279
# 3280
# 3281
# 3284
# 3285
# 3286
# 3287
# 3289
# 3291
# 3293
# 3295
# 3296
# 3298
# 3299
# 3300
# 3307
# 3309
# 3310
# 3311
# 3313
# 3314
# 3315
# 3316
# 3317
# 3319
# 3321
# 3323
# 3324
# 3327
# 3328
# 3329
# 3332
# 3334
# 3335
# 3336
# 3341
# 3342
# 3343
# 3345
# 3351
# 3352
# 3353
# 3355
# 3356
# 3358
# 3359
# 3360
# 3362
# 3363
# 3364
# 3365
# 3366
# 3368
# 3370
# 3372
# 3373
# 3374
# 3376
# 3379
# 3380
# 3381
# 3382
# 3386
# 3388
# 3392
# 3393
# 3394
# 3396
# 3399
# 3400
# 3402
# 3405
# 3407
# 3408
# 3409
# 3411
# 3413
# 3418
# 3419
# 3422
# 3427
# 3431
# 3432
# 3434
# 3436
# 3437
# 3440
# 3441
# 3442
# 3444
# 3445
# 3446
# 3447
# 3448
# 3450
# 3455
# 3456
# 3457
# 3458
# 3459
# 3460
# 3461
# 3462
# 3463
# 3467
# 3472
# 3474
# 3475
# 3476
# 3477
# 3478
# 3480
# 3482
# 3483
# 3485
# 3486
# 3487
# 3489
# 3490
# 3491
# 3493
# 3494
# 3495
# 3499
# 3502
# 3505
# 3506
# 3508
# 3509
# 3510
# 3511
# 3512
# 3519
# 3521
# 3522
# 3524
# 3525
# 3526
# 3530
# 3531
# 3532
# 3533
# 3534
# 3535
# 3536
# 3537
# 3538
# 3539
# 3542
# 3543
# 3544
# 3545
# 3546
# 3547
# 3548
# 3549
# 3550
# 3551
# 3552
# 3554
# 3557
# 3558
# 3559
# 3562
# 3563
# 3564
# 3565
# 3566
# 3572
# 3574
# 3576
# 3578
# 3579
# 3581
# 3584
# 3592
# 3593
# 3594
# 3601
# 3603
# 3604
# 3605
# 3606
# 3607
# 3608
# 3612
# 3613
# 3614
# 3615
# 3617
# 3618
# 3620
# 3621
# 3623
# 3626
# 3627
# 3629
# 3630
# 3631
# 3632
# 3635
# 3636
# 3637
# 3639
# 3641
# 3642
# 3643
# 3644
# 3647
# 3648
# 3650
# 3651
# 3654
# 3658
# 3662
# 3663
# 3664
# 3665
# 3667
# 3668
# 3669
# 3672
# 3673
# 3676
# 3679
# 3680
# 3683
# 3686
# 3687
# 3689
# 3690
# 3692
# 3693
# 3694
# 3695
# 3697
# 3698
# 3700
# 3702
# 3703
# 3705
# 3709
# 3711
# 3712
# 3713
# 3714
# 3716
# 3717
# 3718
# 3722
# 3727
# 3728
# 3729
# 3731
# 3732
# 3737
# 3741
# 3742
# 3743
# 3744
# 3746
# 3747
# 3751
# 3755
# 3756
# 3757
# 3758
# 3759
# 3760
# 3761
# 3762
# 3763
# 3767
# 3768
# 3769
# 3770
# 3773
# 3775
# 3776
# 3778
# 3780
# 3781
# 3782
# 3783
# 3785
# 3786
# 3789
# 3790
# 3792
# 3793
# 3794
# 3795
# 3796
# 3797
# 3798
# 3799
# 3800
# 3803
# 3804
# 3806
# 3810
# 3811
# 3812
# 3813
# 3814
# 3815
# 3818
# 3819
# 3823
# 3824
# 3825
# 3826
# 3827
# 3828
# 3829
# 3830
# 3833
# 3834
# 3835
# 3836
# 3837
# 3838
# 3839
# 3840
# 3842
# 3844
# 3846
# 3847
# 3848
# 3850
# 3852
# 3853
# 3854
# 3855
# 3856
# 3858
# 3860
# 3861
# 3862
# 3863
# 3864
# 3865
# 3867
# 3868
# 3871
# 3872
# 3873
# 3874
# 3875
# 3876
# 3877
# 3879
# 3881
# 3882
# 3885
# 3886
# 3888
# 3889
# 3890
# 3895
# 3896
# 3897
# 3898
# 3899
# 3900
# 0
# 2300

# %%
#delete rows where purchase amount = NaN
session.query(ShoppingTrends).filter(ShoppingTrends.purchase_amount_usd.is_(None)).delete()
session.commit()
# Out:
# 2025-03-14 15:25:41,878 INFO sqlalchemy.engine.Engine DELETE FROM shopping_trends WHERE shopping_trends.`Purchase Amount (USD)` IS NULL
# 2025-03-14 15:25:41,879 INFO sqlalchemy.engine.Engine [generated in 0.00155s] {}
# 2025-03-14 15:25:42,003 INFO sqlalchemy.engine.Engine COMMIT

# %%
#select * from shopping_trends
all_rows = session.query(ShoppingTrends).all()
for row in all_rows:
    print(row)  # This will print the entire object for each row
    #print specific rows: print(user.customer_id, user.age, user.gender, user.item_purchased, user.purchase_amount_usd)
# Out:
# 2025-03-14 15:25:42,053 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-14 15:25:42,056 INFO sqlalchemy.engine.Engine SELECT shopping_trends.`Customer ID` AS `shopping_trends_Customer ID`, shopping_trends.`Age` AS `shopping_trends_Age`, shopping_trends.`Gender` AS `shopping_trends_Gender`, shopping_trends.`Item Purchased` AS `shopping_trends_Item Purchased`, shopping_trends.`Category` AS `shopping_trends_Category`, shopping_trends.`Purchase Amount (USD)` AS `shopping_trends_Purchase Amount (USD)`, shopping_trends.`Location` AS `shopping_trends_Location`, shopping_trends.`Size` AS `shopping_trends_Size`, shopping_trends.`Color` AS `shopping_trends_Color`, shopping_trends.`Season` AS `shopping_trends_Season`, shopping_trends.`Review Rating` AS `shopping_trends_Review Rating`, shopping_trends.`Subscription Status` AS `shopping_trends_Subscription Status`, shopping_trends.`Payment Method` AS `shopping_trends_Payment Method`, shopping_trends.`Shipping Type` AS `shopping_trends_Shipping Type`, shopping_trends.`Discount Applied` AS `shopping_trends_Discount Applied`, shopping_trends.`Promo Code Used` AS `shopping_trends_Promo Code Used`, shopping_trends.`Previous Purchases` AS `shopping_trends_Previous Purchases`, shopping_trends.`Preferred Payment Method` AS `shopping_trends_Preferred Payment Method`, shopping_trends.`Frequency of Purchases` AS `shopping_trends_Frequency of Purchases`
# FROM shopping_trends
# 2025-03-14 15:25:42,058 INFO sqlalchemy.engine.Engine [generated in 0.00131s] {}
# <ShoppingTrends(customer_id=1, age=55, gender='Male', item_purchased='Blouse', category='Clothing', purchase_amount_usd=53, location='Kentucky', size='L', color='Gray', season='Winter', review_rating=3.1, subscription_status='Yes', payment_method='Credit Card', shipping_type='Express', discount_applied='Yes', promo_code_used='Yes', previous_purchases=14, preferred_payment_method='Venmo', frequency_of_purchases='Fortnightly')>
# <ShoppingTrends(customer_id=2, age=19, gender='Male', item_purchased='Sweater', category='Clothing', purchase_amount_usd=64, location='Maine', size='L', color='Maroon', season='Winter', review_rating=3.1, subscription_status='Yes', payment_method='Bank Transfer', shipping_type='Express', discount_applied='Yes', promo_code_used='Yes', previous_purchases=2, preferred_payment_method='Cash', frequency_of_purchases='Fortnightly')>
# <ShoppingTrends(customer_id=3, age=50, gender='Male', item_purchased='Jeans', category='Clothing', purchase_amount_usd=73, location='Massachusetts', size='S', color='Maroon', season='Spring', review_rating=3.1, subscription_status='Yes', payment_method='Cash', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=23, preferred_payment_method='Credit Card', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=4, age=21, gender='Male', item_purchased='Sandals', category='Footwear', purchase_amount_usd=90, location='Rhode Island', size='M', color='Maroon', season='Spring', review_rating=3.5, subscription_status='Yes', payment_method='PayPal', shipping_type='Next Day Air', discount_applied='Yes', promo_code_used='Yes', previous_purchases=49, preferred_payment_method='PayPal', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=5, age=45, gender='Male', item_purchased='Blouse', category='Clothing', purchase_amount_usd=49, location='Oregon', size='M', color='Turquoise', season='Spring', review_rating=2.7, subscription_status='Yes', payment_method='Cash', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=31, preferred_payment_method='PayPal', frequency_of_purchases='Annually')>
# <ShoppingTrends(customer_id=6, age=46, gender='Male', item_purchased='Sneakers', category='Footwear', purchase_amount_usd=20, location='Wyoming', size='M', color='White', season='Summer', review_rating=2.9, subscription_status='Yes', payment_method='Venmo', shipping_type='Standard', discount_applied='Yes', promo_code_used='Yes', previous_purchases=14, preferred_payment_method='Venmo', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=7, age=63, gender='Male', item_purchased='Shirt', category='Clothing', purchase_amount_usd=85, location='Montana', size='M', color='Gray', season='Fall', review_rating=3.2, subscription_status='Yes', payment_method='Debit Card', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=49, preferred_payment_method='Cash', frequency_of_purchases='Quarterly')>
# <ShoppingTrends(customer_id=8, age=27, gender='Male', item_purchased='Shorts', category='Clothing', purchase_amount_usd=34, location='Louisiana', size='L', color='Charcoal', season='Winter', review_rating=3.2, subscription_status='Yes', payment_method='Debit Card', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=19, preferred_payment_method='Credit Card', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=9, age=26, gender='Male', item_purchased='Coat', category='Outerwear', purchase_amount_usd=97, location='West Virginia', size='L', color='Silver', season='Summer', review_rating=2.6, subscription_status='Yes', payment_method='Venmo', shipping_type='Express', discount_applied='Yes', promo_code_used='Yes', previous_purchases=8, preferred_payment_method='Venmo', frequency_of_purchases='Annually')>
# <ShoppingTrends(customer_id=10, age=57, gender='Male', item_purchased='Handbag', category='Accessories', purchase_amount_usd=31, location='Missouri', size='M', color='Pink', season='Spring', review_rating=4.8, subscription_status='Yes', payment_method='PayPal', shipping_type='2-Day Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=4, preferred_payment_method='Cash', frequency_of_purchases='Quarterly')>
# <ShoppingTrends(customer_id=11, age=53, gender='Male', item_purchased='Shoes', category='Footwear', purchase_amount_usd=34, location='Arkansas', size='L', color='Purple', season='Fall', review_rating=4.1, subscription_status='Yes', payment_method='Credit Card', shipping_type='Store Pickup', discount_applied='Yes', promo_code_used='Yes', previous_purchases=26, preferred_payment_method='Bank Transfer', frequency_of_purchases='Bi-Weekly')>
# <ShoppingTrends(customer_id=12, age=30, gender='Male', item_purchased='Shorts', category='Clothing', purchase_amount_usd=68, location='Hawaii', size='S', color='Olive', season='Winter', review_rating=4.9, subscription_status='Yes', payment_method='PayPal', shipping_type='Store Pickup', discount_applied='Yes', promo_code_used='Yes', previous_purchases=10, preferred_payment_method='Bank Transfer', frequency_of_purchases='Fortnightly')>
# <ShoppingTrends(customer_id=13, age=61, gender='Male', item_purchased='Coat', category='Outerwear', purchase_amount_usd=72, location='Delaware', size='M', color='Gold', season='Winter', review_rating=4.5, subscription_status='Yes', payment_method='PayPal', shipping_type='Express', discount_applied='Yes', promo_code_used='Yes', previous_purchases=37, preferred_payment_method='Venmo', frequency_of_purchases='Fortnightly')>
# <ShoppingTrends(customer_id=14, age=65, gender='Male', item_purchased='Dress', category='Clothing', purchase_amount_usd=51, location='New Hampshire', size='M', color='Violet', season='Spring', review_rating=4.7, subscription_status='Yes', payment_method='Debit Card', shipping_type='Express', discount_applied='Yes', promo_code_used='Yes', previous_purchases=31, preferred_payment_method='PayPal', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=15, age=64, gender='Male', item_purchased='Coat', category='Outerwear', purchase_amount_usd=53, location='New York', size='L', color='Teal', season='Winter', review_rating=4.7, subscription_status='Yes', payment_method='PayPal', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=34, preferred_payment_method='Debit Card', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=16, age=64, gender='Male', item_purchased='Skirt', category='Clothing', purchase_amount_usd=81, location='Rhode Island', size='M', color='Teal', season='Winter', review_rating=2.8, subscription_status='Yes', payment_method='Credit Card', shipping_type='Store Pickup', discount_applied='Yes', promo_code_used='Yes', previous_purchases=8, preferred_payment_method='PayPal', frequency_of_purchases='Monthly')>
# <ShoppingTrends(customer_id=17, age=25, gender='Male', item_purchased='Sunglasses', category='Accessories', purchase_amount_usd=36, location='Alabama', size='S', color='Gray', season='Spring', review_rating=4.1, subscription_status='Yes', payment_method='Venmo', shipping_type='Next Day Air', discount_applied='Yes', promo_code_used='Yes', previous_purchases=44, preferred_payment_method='Debit Card', frequency_of_purchases='Bi-Weekly')>
# <ShoppingTrends(customer_id=18, age=53, gender='Male', item_purchased='Dress', category='Clothing', purchase_amount_usd=38, location='Mississippi', size='XL', color='Lavender', season='Winter', review_rating=4.7, subscription_status='Yes', payment_method='Debit Card', shipping_type='2-Day Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=36, preferred_payment_method='Venmo', frequency_of_purchases='Quarterly')>
# <ShoppingTrends(customer_id=19, age=52, gender='Male', item_purchased='Sweater', category='Clothing', purchase_amount_usd=48, location='Montana', size='S', color='Black', season='Summer', review_rating=4.6, subscription_status='Yes', payment_method='Bank Transfer', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=17, preferred_payment_method='Cash', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=20, age=66, gender='Male', item_purchased='Pants', category='Clothing', purchase_amount_usd=90, location='Rhode Island', size='M', color='Green', season='Summer', review_rating=3.3, subscription_status='Yes', payment_method='Venmo', shipping_type='Standard', discount_applied='Yes', promo_code_used='Yes', previous_purchases=46, preferred_payment_method='Debit Card', frequency_of_purchases='Bi-Weekly')>
# <ShoppingTrends(customer_id=21, age=21, gender='Male', item_purchased='Pants', category='Clothing', purchase_amount_usd=51, location='Louisiana', size='M', color='Black', season='Winter', review_rating=2.8, subscription_status='Yes', payment_method='Credit Card', shipping_type='Express', discount_applied='Yes', promo_code_used='Yes', previous_purchases=50, preferred_payment_method='Cash', frequency_of_purchases='Every 3 Months')>
# <ShoppingTrends(customer_id=22, age=31, gender='Male', item_purchased='Pants', category='Clothing', purchase_amount_usd=62, location='North Carolina', size='M', color='Charcoal', season='Winter', review_rating=4.1, subscription_status='Yes', payment_method='Credit Card', shipping_type='Store Pickup', discount_applied='Yes', promo_code_used='Yes', previous_purchases=22, preferred_payment_method='Debit Card', frequency_of_purchases='Quarterly')>
# <ShoppingTrends(customer_id=23, age=56, gender='Male', item_purchased='Pants', category='Clothing', purchase_amount_usd=37, location='California', size='M', color='Peach', season='Summer', review_rating=3.2, subscription_status='Yes', payment_method='Cash', shipping_type='Store Pickup', discount_applied='Yes', promo_code_used='Yes', previous_purchases=32, preferred_payment_method='Debit Card', frequency_of_purchases='Annually')>
# <ShoppingTrends(customer_id=24, age=31, gender='Male', item_purchased='Pants', category='Clothing', purchase_amount_usd=88, location='Oklahoma', size='XL', color='White', season='Winter', review_rating=4.4, subscription_status='Yes', payment_method='Credit Card', shipping_type='Express', discount_applied='Yes', promo_code_used='Yes', previous_purchases=40, preferred_payment_method='Credit Card', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=25, age=18, gender='Male', item_purchased='Jacket', category='Outerwear', purchase_amount_usd=22, location='Florida', size='M', color='Green', season='Fall', review_rating=2.9, subscription_status='Yes', payment_method='Cash', shipping_type='Store Pickup', discount_applied='Yes', promo_code_used='Yes', previous_purchases=16, preferred_payment_method='Debit Card', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=26, age=18, gender='Male', item_purchased='Hoodie', category='Clothing', purchase_amount_usd=25, location='Texas', size='M', color='Silver', season='Summer', review_rating=3.6, subscription_status='Yes', payment_method='Bank Transfer', shipping_type='Express', discount_applied='Yes', promo_code_used='Yes', previous_purchases=14, preferred_payment_method='PayPal', frequency_of_purchases='Annually')>
# <ShoppingTrends(customer_id=27, age=38, gender='Male', item_purchased='Jewelry', category='Accessories', purchase_amount_usd=20, location='Nevada', size='M', color='Red', season='Spring', review_rating=3.6, subscription_status='Yes', payment_method='Cash', shipping_type='Next Day Air', discount_applied='Yes', promo_code_used='Yes', previous_purchases=13, preferred_payment_method='Credit Card', frequency_of_purchases='Annually')>
# <ShoppingTrends(customer_id=28, age=56, gender='Male', item_purchased='Shorts', category='Clothing', purchase_amount_usd=56, location='Kentucky', size='L', color='Cyan', season='Summer', review_rating=5.0, subscription_status='Yes', payment_method='Debit Card', shipping_type='Next Day Air', discount_applied='Yes', promo_code_used='Yes', previous_purchases=7, preferred_payment_method='Bank Transfer', frequency_of_purchases='Every 3 Months')>
# <ShoppingTrends(customer_id=29, age=54, gender='Male', item_purchased='Handbag', category='Accessories', purchase_amount_usd=94, location='North Carolina', size='M', color='Gray', season='Fall', review_rating=4.4, subscription_status='Yes', payment_method='Debit Card', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=41, preferred_payment_method='PayPal', frequency_of_purchases='Every 3 Months')>
# <ShoppingTrends(customer_id=30, age=31, gender='Male', item_purchased='Dress', category='Clothing', purchase_amount_usd=48, location='Wyoming', size='S', color='Black', season='Fall', review_rating=4.1, subscription_status='Yes', payment_method='Venmo', shipping_type='Store Pickup', discount_applied='Yes', promo_code_used='Yes', previous_purchases=14, preferred_payment_method='Credit Card', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=31, age=57, gender='Male', item_purchased='Jewelry', category='Accessories', purchase_amount_usd=31, location='North Carolina', size='L', color='Black', season='Winter', review_rating=4.7, subscription_status='Yes', payment_method='Bank Transfer', shipping_type='Standard', discount_applied='Yes', promo_code_used='Yes', previous_purchases=16, preferred_payment_method='Credit Card', frequency_of_purchases='Monthly')>
# <ShoppingTrends(customer_id=32, age=33, gender='Male', item_purchased='Dress', category='Clothing', purchase_amount_usd=79, location='West Virginia', size='L', color='Brown', season='Winter', review_rating=4.7, subscription_status='Yes', payment_method='Venmo', shipping_type='Store Pickup', discount_applied='Yes', promo_code_used='Yes', previous_purchases=45, preferred_payment_method='Venmo', frequency_of_purchases='Monthly')>
# <ShoppingTrends(customer_id=33, age=36, gender='Male', item_purchased='Jacket', category='Outerwear', purchase_amount_usd=67, location='Kansas', size='M', color='Silver', season='Summer', review_rating=4.9, subscription_status='Yes', payment_method='Bank Transfer', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=37, preferred_payment_method='Venmo', frequency_of_purchases='Annually')>
# <ShoppingTrends(customer_id=34, age=54, gender='Male', item_purchased='Pants', category='Clothing', purchase_amount_usd=38, location='Colorado', size='L', color='Green', season='Summer', review_rating=3.3, subscription_status='Yes', payment_method='Venmo', shipping_type='Store Pickup', discount_applied='Yes', promo_code_used='Yes', previous_purchases=45, preferred_payment_method='Cash', frequency_of_purchases='Quarterly')>
# <ShoppingTrends(customer_id=35, age=36, gender='Male', item_purchased='T-shirt', category='Clothing', purchase_amount_usd=91, location='North Dakota', size='L', color='Violet', season='Spring', review_rating=4.6, subscription_status='Yes', payment_method='Debit Card', shipping_type='2-Day Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=38, preferred_payment_method='PayPal', frequency_of_purchases='Quarterly')>
# <ShoppingTrends(customer_id=36, age=54, gender='Male', item_purchased='Blouse', category='Clothing', purchase_amount_usd=33, location='Massachusetts', size='M', color='Cyan', season='Summer', review_rating=4.0, subscription_status='Yes', payment_method='Bank Transfer', shipping_type='2-Day Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=48, preferred_payment_method='Credit Card', frequency_of_purchases='Bi-Weekly')>
# <ShoppingTrends(customer_id=37, age=35, gender='Male', item_purchased='T-shirt', category='Clothing', purchase_amount_usd=69, location='Illinois', size='M', color='Maroon', season='Winter', review_rating=4.6, subscription_status='Yes', payment_method='Cash', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=44, preferred_payment_method='PayPal', frequency_of_purchases='Fortnightly')>
# <ShoppingTrends(customer_id=38, age=35, gender='Male', item_purchased='Jeans', category='Clothing', purchase_amount_usd=45, location='Indiana', size='S', color='Cyan', season='Summer', review_rating=2.8, subscription_status='Yes', payment_method='Debit Card', shipping_type='Store Pickup', discount_applied='Yes', promo_code_used='Yes', previous_purchases=10, preferred_payment_method='PayPal', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=39, age=29, gender='Male', item_purchased='Dress', category='Clothing', purchase_amount_usd=37, location='Florida', size='M', color='Red', season='Winter', review_rating=3.7, subscription_status='Yes', payment_method='Debit Card', shipping_type='2-Day Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=44, preferred_payment_method='Venmo', frequency_of_purchases='Every 3 Months')>
# <ShoppingTrends(customer_id=40, age=70, gender='Male', item_purchased='Pants', category='Clothing', purchase_amount_usd=60, location='Arizona', size='S', color='Turquoise', season='Summer', review_rating=4.2, subscription_status='Yes', payment_method='Bank Transfer', shipping_type='Express', discount_applied='Yes', promo_code_used='Yes', previous_purchases=18, preferred_payment_method='Credit Card', frequency_of_purchases='Monthly')>
# <ShoppingTrends(customer_id=41, age=69, gender='Male', item_purchased='Handbag', category='Accessories', purchase_amount_usd=76, location='Louisiana', size='L', color='Beige', season='Winter', review_rating=4.6, subscription_status='Yes', payment_method='PayPal', shipping_type='Next Day Air', discount_applied='Yes', promo_code_used='Yes', previous_purchases=31, preferred_payment_method='Debit Card', frequency_of_purchases='Quarterly')>
# <ShoppingTrends(customer_id=42, age=67, gender='Male', item_purchased='Scarf', category='Accessories', purchase_amount_usd=39, location='Alaska', size='M', color='Orange', season='Spring', review_rating=4.5, subscription_status='Yes', payment_method='Cash', shipping_type='Standard', discount_applied='Yes', promo_code_used='Yes', previous_purchases=40, preferred_payment_method='Venmo', frequency_of_purchases='Annually')>
# <ShoppingTrends(customer_id=43, age=20, gender='Male', item_purchased='Coat', category='Outerwear', purchase_amount_usd=100, location='Tennessee', size='M', color='Beige', season='Spring', review_rating=4.1, subscription_status='Yes', payment_method='Bank Transfer', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=15, preferred_payment_method='PayPal', frequency_of_purchases='Annually')>
# <ShoppingTrends(customer_id=44, age=25, gender='Male', item_purchased='Scarf', category='Accessories', purchase_amount_usd=69, location='Ohio', size='L', color='Lavender', season='Fall', review_rating=3.7, subscription_status='Yes', payment_method='PayPal', shipping_type='Store Pickup', discount_applied='Yes', promo_code_used='Yes', previous_purchases=19, preferred_payment_method='PayPal', frequency_of_purchases='Fortnightly')>
# <ShoppingTrends(customer_id=45, age=39, gender='Male', item_purchased='Hat', category='Accessories', purchase_amount_usd=53, location='Kentucky', size='S', color='Silver', season='Summer', review_rating=4.6, subscription_status='Yes', payment_method='Bank Transfer', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=45, preferred_payment_method='PayPal', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=46, age=50, gender='Male', item_purchased='Socks', category='Clothing', purchase_amount_usd=21, location='Tennessee', size='XL', color='Indigo', season='Fall', review_rating=2.9, subscription_status='Yes', payment_method='Venmo', shipping_type='2-Day Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=25, preferred_payment_method='PayPal', frequency_of_purchases='Annually')>
# <ShoppingTrends(customer_id=47, age=57, gender='Male', item_purchased='Shirt', category='Clothing', purchase_amount_usd=43, location='California', size='L', color='White', season='Summer', review_rating=2.9, subscription_status='Yes', payment_method='Venmo', shipping_type='Store Pickup', discount_applied='Yes', promo_code_used='Yes', previous_purchases=45, preferred_payment_method='Cash', frequency_of_purchases='Quarterly')>
# <ShoppingTrends(customer_id=48, age=55, gender='Male', item_purchased='Jewelry', category='Accessories', purchase_amount_usd=54, location='Montana', size='M', color='Charcoal', season='Winter', review_rating=4.5, subscription_status='Yes', payment_method='Debit Card', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=36, preferred_payment_method='Cash', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=49, age=42, gender='Male', item_purchased='Shirt', category='Clothing', purchase_amount_usd=55, location='Nevada', size='M', color='Orange', season='Summer', review_rating=2.7, subscription_status='Yes', payment_method='Debit Card', shipping_type='Store Pickup', discount_applied='Yes', promo_code_used='Yes', previous_purchases=38, preferred_payment_method='Cash', frequency_of_purchases='Monthly')>
# <ShoppingTrends(customer_id=50, age=68, gender='Male', item_purchased='Hoodie', category='Clothing', purchase_amount_usd=30, location='New Jersey', size='S', color='Indigo', season='Spring', review_rating=4.6, subscription_status='Yes', payment_method='Bank Transfer', shipping_type='Next Day Air', discount_applied='Yes', promo_code_used='Yes', previous_purchases=34, preferred_payment_method='Debit Card', frequency_of_purchases='Bi-Weekly')>
# <ShoppingTrends(customer_id=51, age=49, gender='Male', item_purchased='Blouse', category='Clothing', purchase_amount_usd=28, location='Maryland', size='M', color='Red', season='Spring', review_rating=3.7, subscription_status='Yes', payment_method='Cash', shipping_type='Store Pickup', discount_applied='Yes', promo_code_used='Yes', previous_purchases=39, preferred_payment_method='Debit Card', frequency_of_purchases='Bi-Weekly')>
# <ShoppingTrends(customer_id=52, age=59, gender='Male', item_purchased='Skirt', category='Clothing', purchase_amount_usd=59, location='Vermont', size='XL', color='Gray', season='Winter', review_rating=4.7, subscription_status='Yes', payment_method='PayPal', shipping_type='2-Day Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=7, preferred_payment_method='Credit Card', frequency_of_purchases='Quarterly')>
# <ShoppingTrends(customer_id=53, age=42, gender='Male', item_purchased='T-shirt', category='Clothing', purchase_amount_usd=20, location='Alaska', size='M', color='Green', season='Summer', review_rating=2.6, subscription_status='Yes', payment_method='Credit Card', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=26, preferred_payment_method='Credit Card', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=54, age=29, gender='Male', item_purchased='Skirt', category='Clothing', purchase_amount_usd=24, location='Mississippi', size='S', color='Peach', season='Winter', review_rating=3.9, subscription_status='Yes', payment_method='Debit Card', shipping_type='Next Day Air', discount_applied='Yes', promo_code_used='Yes', previous_purchases=35, preferred_payment_method='Credit Card', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=55, age=47, gender='Male', item_purchased='Coat', category='Outerwear', purchase_amount_usd=94, location='New Mexico', size='M', color='Brown', season='Summer', review_rating=4.2, subscription_status='Yes', payment_method='Bank Transfer', shipping_type='Next Day Air', discount_applied='Yes', promo_code_used='Yes', previous_purchases=35, preferred_payment_method='Debit Card', frequency_of_purchases='Bi-Weekly')>
# <ShoppingTrends(customer_id=56, age=40, gender='Male', item_purchased='Jacket', category='Outerwear', purchase_amount_usd=28, location='South Carolina', size='M', color='Lavender', season='Winter', review_rating=3.0, subscription_status='Yes', payment_method='Venmo', shipping_type='2-Day Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=49, preferred_payment_method='Credit Card', frequency_of_purchases='Annually')>
# <ShoppingTrends(customer_id=57, age=41, gender='Male', item_purchased='Backpack', category='Accessories', purchase_amount_usd=73, location='Mississippi', size='XL', color='Brown', season='Summer', review_rating=4.7, subscription_status='Yes', payment_method='PayPal', shipping_type='Store Pickup', discount_applied='Yes', promo_code_used='Yes', previous_purchases=46, preferred_payment_method='Credit Card', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=58, age=21, gender='Male', item_purchased='Coat', category='Outerwear', purchase_amount_usd=64, location='West Virginia', size='M', color='White', season='Summer', review_rating=4.4, subscription_status='Yes', payment_method='PayPal', shipping_type='Store Pickup', discount_applied='Yes', promo_code_used='Yes', previous_purchases=17, preferred_payment_method='Debit Card', frequency_of_purchases='Fortnightly')>
# <ShoppingTrends(customer_id=59, age=69, gender='Male', item_purchased='Hoodie', category='Clothing', purchase_amount_usd=54, location='Missouri', size='M', color='Charcoal', season='Summer', review_rating=4.2, subscription_status='Yes', payment_method='Credit Card', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=29, preferred_payment_method='Venmo', frequency_of_purchases='Monthly')>
# <ShoppingTrends(customer_id=60, age=63, gender='Male', item_purchased='Belt', category='Accessories', purchase_amount_usd=79, location='Louisiana', size='L', color='Yellow', season='Spring', review_rating=4.6, subscription_status='Yes', payment_method='Debit Card', shipping_type='Standard', discount_applied='Yes', promo_code_used='Yes', previous_purchases=4, preferred_payment_method='Debit Card', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=61, age=50, gender='Male', item_purchased='Sweater', category='Clothing', purchase_amount_usd=37, location='Idaho', size='L', color='Brown', season='Summer', review_rating=4.0, subscription_status='Yes', payment_method='Credit Card', shipping_type='Express', discount_applied='Yes', promo_code_used='Yes', previous_purchases=17, preferred_payment_method='Cash', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=62, age=55, gender='Male', item_purchased='Scarf', category='Accessories', purchase_amount_usd=68, location='Texas', size='M', color='Orange', season='Winter', review_rating=4.7, subscription_status='Yes', payment_method='Bank Transfer', shipping_type='Store Pickup', discount_applied='Yes', promo_code_used='Yes', previous_purchases=21, preferred_payment_method='Credit Card', frequency_of_purchases='Every 3 Months')>
# <ShoppingTrends(customer_id=63, age=30, gender='Male', item_purchased='Sneakers', category='Footwear', purchase_amount_usd=21, location='Mississippi', size='S', color='Magenta', season='Spring', review_rating=3.8, subscription_status='Yes', payment_method='Credit Card', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=31, preferred_payment_method='Credit Card', frequency_of_purchases='Fortnightly')>
# <ShoppingTrends(customer_id=64, age=33, gender='Male', item_purchased='Sunglasses', category='Accessories', purchase_amount_usd=79, location='Arizona', size='L', color='Lavender', season='Winter', review_rating=2.7, subscription_status='Yes', payment_method='Credit Card', shipping_type='2-Day Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=43, preferred_payment_method='Credit Card', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=65, age=65, gender='Male', item_purchased='Boots', category='Footwear', purchase_amount_usd=83, location='Alabama', size='S', color='Green', season='Fall', review_rating=4.8, subscription_status='Yes', payment_method='PayPal', shipping_type='Standard', discount_applied='Yes', promo_code_used='Yes', previous_purchases=18, preferred_payment_method='Debit Card', frequency_of_purchases='Fortnightly')>
# <ShoppingTrends(customer_id=66, age=65, gender='Male', item_purchased='Backpack', category='Accessories', purchase_amount_usd=36, location='New Jersey', size='M', color='Purple', season='Spring', review_rating=4.8, subscription_status='Yes', payment_method='Credit Card', shipping_type='2-Day Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=44, preferred_payment_method='Venmo', frequency_of_purchases='Every 3 Months')>
# <ShoppingTrends(customer_id=67, age=31, gender='Male', item_purchased='Blouse', category='Clothing', purchase_amount_usd=94, location='Pennsylvania', size='S', color='Magenta', season='Winter', review_rating=4.7, subscription_status='Yes', payment_method='Bank Transfer', shipping_type='2-Day Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=3, preferred_payment_method='Venmo', frequency_of_purchases='Every 3 Months')>
# <ShoppingTrends(customer_id=68, age=45, gender='Male', item_purchased='Coat', category='Outerwear', purchase_amount_usd=33, location='Connecticut', size='L', color='Gray', season='Winter', review_rating=4.4, subscription_status='Yes', payment_method='PayPal', shipping_type='Store Pickup', discount_applied='Yes', promo_code_used='Yes', previous_purchases=49, preferred_payment_method='Debit Card', frequency_of_purchases='Monthly')>
# <ShoppingTrends(customer_id=69, age=57, gender='Male', item_purchased='Handbag', category='Accessories', purchase_amount_usd=46, location='Utah', size='L', color='Silver', season='Summer', review_rating=3.9, subscription_status='Yes', payment_method='Credit Card', shipping_type='Next Day Air', discount_applied='Yes', promo_code_used='Yes', previous_purchases=21, preferred_payment_method='Cash', frequency_of_purchases='Every 3 Months')>
# <ShoppingTrends(customer_id=70, age=48, gender='Male', item_purchased='Belt', category='Accessories', purchase_amount_usd=70, location='Tennessee', size='S', color='Cyan', season='Summer', review_rating=4.4, subscription_status='Yes', payment_method='Credit Card', shipping_type='Express', discount_applied='Yes', promo_code_used='Yes', previous_purchases=5, preferred_payment_method='Cash', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=71, age=22, gender='Male', item_purchased='Belt', category='Accessories', purchase_amount_usd=29, location='Alabama', size='M', color='Magenta', season='Fall', review_rating=4.2, subscription_status='Yes', payment_method='Credit Card', shipping_type='Express', discount_applied='Yes', promo_code_used='Yes', previous_purchases=32, preferred_payment_method='Debit Card', frequency_of_purchases='Every 3 Months')>
# <ShoppingTrends(customer_id=72, age=36, gender='Male', item_purchased='Dress', category='Clothing', purchase_amount_usd=48, location='Virginia', size='L', color='Gold', season='Summer', review_rating=2.9, subscription_status='Yes', payment_method='Debit Card', shipping_type='Express', discount_applied='Yes', promo_code_used='Yes', previous_purchases=34, preferred_payment_method='Bank Transfer', frequency_of_purchases='Annually')>
# <ShoppingTrends(customer_id=73, age=18, gender='Male', item_purchased='Dress', category='Clothing', purchase_amount_usd=26, location='Georgia', size='M', color='Olive', season='Winter', review_rating=2.9, subscription_status='Yes', payment_method='Debit Card', shipping_type='Store Pickup', discount_applied='Yes', promo_code_used='Yes', previous_purchases=21, preferred_payment_method='Bank Transfer', frequency_of_purchases='Every 3 Months')>
# <ShoppingTrends(customer_id=74, age=48, gender='Male', item_purchased='Pants', category='Clothing', purchase_amount_usd=85, location='Hawaii', size='M', color='Teal', season='Spring', review_rating=2.7, subscription_status='Yes', payment_method='Debit Card', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=43, preferred_payment_method='Bank Transfer', frequency_of_purchases='Bi-Weekly')>
# <ShoppingTrends(customer_id=75, age=49, gender='Male', item_purchased='Gloves', category='Accessories', purchase_amount_usd=58, location='Indiana', size='L', color='Violet', season='Spring', review_rating=4.5, subscription_status='Yes', payment_method='PayPal', shipping_type='Express', discount_applied='Yes', promo_code_used='Yes', previous_purchases=3, preferred_payment_method='Cash', frequency_of_purchases='Monthly')>
# <ShoppingTrends(customer_id=76, age=64, gender='Male', item_purchased='Scarf', category='Accessories', purchase_amount_usd=85, location='Utah', size='M', color='Blue', season='Summer', review_rating=2.7, subscription_status='Yes', payment_method='Debit Card', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=21, preferred_payment_method='Credit Card', frequency_of_purchases='Annually')>
# <ShoppingTrends(customer_id=77, age=50, gender='Male', item_purchased='Hat', category='Accessories', purchase_amount_usd=43, location='Delaware', size='S', color='Teal', season='Summer', review_rating=4.2, subscription_status='Yes', payment_method='Bank Transfer', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=32, preferred_payment_method='Venmo', frequency_of_purchases='Monthly')>
# <ShoppingTrends(customer_id=78, age=22, gender='Male', item_purchased='Dress', category='Clothing', purchase_amount_usd=53, location='Delaware', size='L', color='Gold', season='Summer', review_rating=3.3, subscription_status='Yes', payment_method='Debit Card', shipping_type='Next Day Air', discount_applied='Yes', promo_code_used='Yes', previous_purchases=36, preferred_payment_method='Debit Card', frequency_of_purchases='Fortnightly')>
# <ShoppingTrends(customer_id=79, age=50, gender='Male', item_purchased='Skirt', category='Clothing', purchase_amount_usd=91, location='Nebraska', size='M', color='Maroon', season='Spring', review_rating=4.7, subscription_status='Yes', payment_method='Venmo', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=50, preferred_payment_method='Venmo', frequency_of_purchases='Fortnightly')>
# <ShoppingTrends(customer_id=80, age=38, gender='Male', item_purchased='Jacket', category='Outerwear', purchase_amount_usd=96, location='Iowa', size='M', color='Olive', season='Winter', review_rating=2.6, subscription_status='Yes', payment_method='Bank Transfer', shipping_type='2-Day Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=43, preferred_payment_method='Bank Transfer', frequency_of_purchases='Every 3 Months')>
# <ShoppingTrends(customer_id=81, age=19, gender='Male', item_purchased='Sandals', category='Footwear', purchase_amount_usd=72, location='New York', size='XL', color='Blue', season='Summer', review_rating=3.3, subscription_status='Yes', payment_method='Credit Card', shipping_type='Store Pickup', discount_applied='Yes', promo_code_used='Yes', previous_purchases=24, preferred_payment_method='Credit Card', frequency_of_purchases='Every 3 Months')>
# <ShoppingTrends(customer_id=82, age=67, gender='Male', item_purchased='Shoes', category='Footwear', purchase_amount_usd=96, location='Virginia', size='L', color='Maroon', season='Summer', review_rating=2.6, subscription_status='Yes', payment_method='PayPal', shipping_type='Express', discount_applied='Yes', promo_code_used='Yes', previous_purchases=36, preferred_payment_method='Credit Card', frequency_of_purchases='Every 3 Months')>
# <ShoppingTrends(customer_id=83, age=19, gender='Male', item_purchased='Pants', category='Clothing', purchase_amount_usd=28, location='Georgia', size='S', color='Olive', season='Spring', review_rating=4.0, subscription_status='Yes', payment_method='Bank Transfer', shipping_type='2-Day Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=21, preferred_payment_method='Credit Card', frequency_of_purchases='Every 3 Months')>
# <ShoppingTrends(customer_id=84, age=36, gender='Male', item_purchased='Dress', category='Clothing', purchase_amount_usd=40, location='Texas', size='M', color='Turquoise', season='Summer', review_rating=4.1, subscription_status='Yes', payment_method='Debit Card', shipping_type='Standard', discount_applied='Yes', promo_code_used='Yes', previous_purchases=34, preferred_payment_method='Bank Transfer', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=85, age=52, gender='Male', item_purchased='Coat', category='Outerwear', purchase_amount_usd=32, location='Arizona', size='S', color='Peach', season='Spring', review_rating=4.4, subscription_status='Yes', payment_method='Cash', shipping_type='Standard', discount_applied='Yes', promo_code_used='Yes', previous_purchases=42, preferred_payment_method='Bank Transfer', frequency_of_purchases='Every 3 Months')>
# <ShoppingTrends(customer_id=86, age=53, gender='Male', item_purchased='Sunglasses', category='Accessories', purchase_amount_usd=95, location='New Mexico', size='M', color='Charcoal', season='Winter', review_rating=4.5, subscription_status='Yes', payment_method='Credit Card', shipping_type='Next Day Air', discount_applied='Yes', promo_code_used='Yes', previous_purchases=2, preferred_payment_method='Debit Card', frequency_of_purchases='Bi-Weekly')>
# <ShoppingTrends(customer_id=87, age=24, gender='Male', item_purchased='Hoodie', category='Clothing', purchase_amount_usd=41, location='Nevada', size='L', color='Pink', season='Spring', review_rating=3.7, subscription_status='Yes', payment_method='Venmo', shipping_type='2-Day Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=47, preferred_payment_method='Cash', frequency_of_purchases='Bi-Weekly')>
# <ShoppingTrends(customer_id=88, age=52, gender='Male', item_purchased='Shoes', category='Footwear', purchase_amount_usd=53, location='Ohio', size='M', color='Green', season='Fall', review_rating=3.7, subscription_status='Yes', payment_method='Debit Card', shipping_type='2-Day Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=44, preferred_payment_method='Debit Card', frequency_of_purchases='Fortnightly')>
# <ShoppingTrends(customer_id=89, age=33, gender='Male', item_purchased='T-shirt', category='Clothing', purchase_amount_usd=47, location='Wyoming', size='M', color='Orange', season='Fall', review_rating=3.5, subscription_status='Yes', payment_method='Credit Card', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=35, preferred_payment_method='Credit Card', frequency_of_purchases='Monthly')>
# <ShoppingTrends(customer_id=90, age=47, gender='Male', item_purchased='Jacket', category='Outerwear', purchase_amount_usd=83, location='California', size='XL', color='Pink', season='Fall', review_rating=3.6, subscription_status='Yes', payment_method='Bank Transfer', shipping_type='Next Day Air', discount_applied='Yes', promo_code_used='Yes', previous_purchases=15, preferred_payment_method='Cash', frequency_of_purchases='Quarterly')>
# <ShoppingTrends(customer_id=91, age=25, gender='Male', item_purchased='Hat', category='Accessories', purchase_amount_usd=48, location='South Carolina', size='L', color='Violet', season='Summer', review_rating=2.9, subscription_status='Yes', payment_method='Venmo', shipping_type='Express', discount_applied='Yes', promo_code_used='Yes', previous_purchases=29, preferred_payment_method='Credit Card', frequency_of_purchases='Monthly')>
# <ShoppingTrends(customer_id=92, age=44, gender='Male', item_purchased='Scarf', category='Accessories', purchase_amount_usd=99, location='South Carolina', size='S', color='Green', season='Winter', review_rating=4.6, subscription_status='Yes', payment_method='PayPal', shipping_type='Standard', discount_applied='Yes', promo_code_used='Yes', previous_purchases=18, preferred_payment_method='Credit Card', frequency_of_purchases='Every 3 Months')>
# <ShoppingTrends(customer_id=93, age=61, gender='Male', item_purchased='Jacket', category='Outerwear', purchase_amount_usd=87, location='Texas', size='M', color='Olive', season='Winter', review_rating=4.4, subscription_status='Yes', payment_method='Cash', shipping_type='2-Day Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=13, preferred_payment_method='Venmo', frequency_of_purchases='Every 3 Months')>
# <ShoppingTrends(customer_id=94, age=37, gender='Male', item_purchased='Sweater', category='Clothing', purchase_amount_usd=62, location='Florida', size='M', color='Purple', season='Fall', review_rating=4.5, subscription_status='Yes', payment_method='PayPal', shipping_type='Standard', discount_applied='Yes', promo_code_used='Yes', previous_purchases=46, preferred_payment_method='Credit Card', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=95, age=58, gender='Male', item_purchased='Skirt', category='Clothing', purchase_amount_usd=76, location='Nevada', size='S', color='Silver', season='Spring', review_rating=4.6, subscription_status='Yes', payment_method='Bank Transfer', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=28, preferred_payment_method='Credit Card', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=96, age=37, gender='Male', item_purchased='Sneakers', category='Footwear', purchase_amount_usd=100, location='Missouri', size='L', color='Pink', season='Fall', review_rating=3.8, subscription_status='Yes', payment_method='PayPal', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=48, preferred_payment_method='PayPal', frequency_of_purchases='Monthly')>
# <ShoppingTrends(customer_id=97, age=32, gender='Male', item_purchased='Gloves', category='Accessories', purchase_amount_usd=73, location='Delaware', size='S', color='Gold', season='Spring', review_rating=3.6, subscription_status='Yes', payment_method='Venmo', shipping_type='Express', discount_applied='Yes', promo_code_used='Yes', previous_purchases=43, preferred_payment_method='Venmo', frequency_of_purchases='Every 3 Months')>
# <ShoppingTrends(customer_id=98, age=21, gender='Male', item_purchased='Shoes', category='Footwear', purchase_amount_usd=92, location='Virginia', size='M', color='Teal', season='Winter', review_rating=4.8, subscription_status='Yes', payment_method='PayPal', shipping_type='Store Pickup', discount_applied='Yes', promo_code_used='Yes', previous_purchases=37, preferred_payment_method='Cash', frequency_of_purchases='Annually')>
# <ShoppingTrends(customer_id=99, age=20, gender='Male', item_purchased='Jeans', category='Clothing', purchase_amount_usd=67, location='New York', size='XL', color='Teal', season='Spring', review_rating=2.6, subscription_status='Yes', payment_method='Cash', shipping_type='Next Day Air', discount_applied='Yes', promo_code_used='Yes', previous_purchases=20, preferred_payment_method='Bank Transfer', frequency_of_purchases='Annually')>
# <ShoppingTrends(customer_id=100, age=26, gender='Male', item_purchased='Hoodie', category='Clothing', purchase_amount_usd=40, location='Missouri', size='XL', color='Indigo', season='Summer', review_rating=3.7, subscription_status='Yes', payment_method='Cash', shipping_type='Express', discount_applied='Yes', promo_code_used='Yes', previous_purchases=33, preferred_payment_method='Debit Card', frequency_of_purchases='Quarterly')>
# <ShoppingTrends(customer_id=101, age=62, gender='Male', item_purchased='Sunglasses', category='Accessories', purchase_amount_usd=98, location='South Dakota', size='M', color='Maroon', season='Fall', review_rating=2.7, subscription_status='Yes', payment_method='PayPal', shipping_type='Express', discount_applied='Yes', promo_code_used='Yes', previous_purchases=31, preferred_payment_method='Cash', frequency_of_purchases='Fortnightly')>
# <ShoppingTrends(customer_id=102, age=27, gender='Male', item_purchased='Coat', category='Outerwear', purchase_amount_usd=85, location='North Dakota', size='XL', color='White', season='Spring', review_rating=4.6, subscription_status='Yes', payment_method='Venmo', shipping_type='Express', discount_applied='Yes', promo_code_used='Yes', previous_purchases=50, preferred_payment_method='Credit Card', frequency_of_purchases='Bi-Weekly')>
# <ShoppingTrends(customer_id=103, age=51, gender='Male', item_purchased='Socks', category='Clothing', purchase_amount_usd=67, location='Oklahoma', size='L', color='Violet', season='Winter', review_rating=4.8, subscription_status='Yes', payment_method='Credit Card', shipping_type='Next Day Air', discount_applied='Yes', promo_code_used='Yes', previous_purchases=35, preferred_payment_method='Credit Card', frequency_of_purchases='Quarterly')>
# <ShoppingTrends(customer_id=104, age=54, gender='Male', item_purchased='Boots', category='Footwear', purchase_amount_usd=89, location='West Virginia', size='L', color='Red', season='Winter', review_rating=4.0, subscription_status='Yes', payment_method='Debit Card', shipping_type='Next Day Air', discount_applied='Yes', promo_code_used='Yes', previous_purchases=22, preferred_payment_method='Venmo', frequency_of_purchases='Bi-Weekly')>
# <ShoppingTrends(customer_id=105, age=55, gender='Male', item_purchased='Sunglasses', category='Accessories', purchase_amount_usd=24, location='New Hampshire', size='L', color='Pink', season='Spring', review_rating=4.4, subscription_status='Yes', payment_method='Bank Transfer', shipping_type='2-Day Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=1, preferred_payment_method='PayPal', frequency_of_purchases='Monthly')>
# <ShoppingTrends(customer_id=106, age=69, gender='Male', item_purchased='Backpack', category='Accessories', purchase_amount_usd=96, location='New York', size='M', color='Charcoal', season='Fall', review_rating=3.6, subscription_status='Yes', payment_method='Bank Transfer', shipping_type='Next Day Air', discount_applied='Yes', promo_code_used='Yes', previous_purchases=4, preferred_payment_method='Bank Transfer', frequency_of_purchases='Annually')>
# ...
# <ShoppingTrends(customer_id=3867, age=58, gender='Female', item_purchased='Hat', category='Accessories', purchase_amount_usd=32, location='Alaska', size='M', color='Beige', season='Winter', review_rating=3.3, subscription_status='No', payment_method='Venmo', shipping_type='2-Day Shipping', discount_applied='No', promo_code_used='No', previous_purchases=33, preferred_payment_method='Credit Card', frequency_of_purchases='Fortnightly')>
# <ShoppingTrends(customer_id=3868, age=46, gender='Female', item_purchased='Jacket', category='Outerwear', purchase_amount_usd=21, location='Maryland', size='L', color='Lavender', season='Summer', review_rating=2.7, subscription_status='No', payment_method='Cash', shipping_type='Standard', discount_applied='No', promo_code_used='No', previous_purchases=28, preferred_payment_method='Credit Card', frequency_of_purchases='Monthly')>
# <ShoppingTrends(customer_id=3869, age=18, gender='Female', item_purchased='Dress', category='Clothing', purchase_amount_usd=29, location='Maryland', size='XL', color='Magenta', season='Winter', review_rating=3.3, subscription_status='No', payment_method='PayPal', shipping_type='2-Day Shipping', discount_applied='No', promo_code_used='No', previous_purchases=9, preferred_payment_method='Cash', frequency_of_purchases='Annually')>
# <ShoppingTrends(customer_id=3870, age=26, gender='Female', item_purchased='Coat', category='Outerwear', purchase_amount_usd=64, location='Arizona', size='L', color='Cyan', season='Spring', review_rating=3.8, subscription_status='No', payment_method='Bank Transfer', shipping_type='Free Shipping', discount_applied='No', promo_code_used='No', previous_purchases=28, preferred_payment_method='Bank Transfer', frequency_of_purchases='Annually')>
# <ShoppingTrends(customer_id=3871, age=61, gender='Female', item_purchased='Sandals', category='Footwear', purchase_amount_usd=46, location='Ohio', size='L', color='Lavender', season='Fall', review_rating=3.2, subscription_status='No', payment_method='Bank Transfer', shipping_type='Next Day Air', discount_applied='No', promo_code_used='No', previous_purchases=19, preferred_payment_method='Cash', frequency_of_purchases='Every 3 Months')>
# <ShoppingTrends(customer_id=3872, age=55, gender='Female', item_purchased='T-shirt', category='Clothing', purchase_amount_usd=97, location='Minnesota', size='M', color='Black', season='Fall', review_rating=4.1, subscription_status='No', payment_method='Credit Card', shipping_type='2-Day Shipping', discount_applied='No', promo_code_used='No', previous_purchases=20, preferred_payment_method='Bank Transfer', frequency_of_purchases='Every 3 Months')>
# <ShoppingTrends(customer_id=3873, age=41, gender='Female', item_purchased='Jacket', category='Outerwear', purchase_amount_usd=94, location='New Hampshire', size='M', color='Green', season='Spring', review_rating=4.3, subscription_status='No', payment_method='Cash', shipping_type='Standard', discount_applied='No', promo_code_used='No', previous_purchases=3, preferred_payment_method='Cash', frequency_of_purchases='Monthly')>
# <ShoppingTrends(customer_id=3874, age=42, gender='Female', item_purchased='Sandals', category='Footwear', purchase_amount_usd=43, location='Louisiana', size='L', color='Silver', season='Summer', review_rating=4.0, subscription_status='No', payment_method='PayPal', shipping_type='Standard', discount_applied='No', promo_code_used='No', previous_purchases=22, preferred_payment_method='Credit Card', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=3875, age=70, gender='Female', item_purchased='Sweater', category='Clothing', purchase_amount_usd=54, location='Nevada', size='XL', color='Beige', season='Summer', review_rating=3.9, subscription_status='No', payment_method='Cash', shipping_type='2-Day Shipping', discount_applied='No', promo_code_used='No', previous_purchases=33, preferred_payment_method='Credit Card', frequency_of_purchases='Bi-Weekly')>
# <ShoppingTrends(customer_id=3876, age=63, gender='Female', item_purchased='Hat', category='Accessories', purchase_amount_usd=51, location='New Hampshire', size='M', color='Pink', season='Winter', review_rating=3.3, subscription_status='No', payment_method='Venmo', shipping_type='2-Day Shipping', discount_applied='No', promo_code_used='No', previous_purchases=21, preferred_payment_method='Credit Card', frequency_of_purchases='Annually')>
# <ShoppingTrends(customer_id=3877, age=60, gender='Female', item_purchased='Shoes', category='Footwear', purchase_amount_usd=85, location='Wisconsin', size='S', color='Cyan', season='Fall', review_rating=2.6, subscription_status='No', payment_method='Bank Transfer', shipping_type='2-Day Shipping', discount_applied='No', promo_code_used='No', previous_purchases=7, preferred_payment_method='Cash', frequency_of_purchases='Annually')>
# <ShoppingTrends(customer_id=3878, age=28, gender='Female', item_purchased='Hoodie', category='Clothing', purchase_amount_usd=96, location='Nevada', size='M', color='Olive', season='Spring', review_rating=4.2, subscription_status='No', payment_method='Venmo', shipping_type='Next Day Air', discount_applied='No', promo_code_used='No', previous_purchases=46, preferred_payment_method='Debit Card', frequency_of_purchases='Monthly')>
# <ShoppingTrends(customer_id=3879, age=60, gender='Female', item_purchased='Hat', category='Accessories', purchase_amount_usd=42, location='South Carolina', size='M', color='Pink', season='Summer', review_rating=3.4, subscription_status='No', payment_method='Venmo', shipping_type='2-Day Shipping', discount_applied='No', promo_code_used='No', previous_purchases=24, preferred_payment_method='Credit Card', frequency_of_purchases='Annually')>
# <ShoppingTrends(customer_id=3880, age=26, gender='Female', item_purchased='Skirt', category='Clothing', purchase_amount_usd=63, location='Florida', size='L', color='Maroon', season='Winter', review_rating=4.1, subscription_status='No', payment_method='Cash', shipping_type='Free Shipping', discount_applied='No', promo_code_used='No', previous_purchases=6, preferred_payment_method='Debit Card', frequency_of_purchases='Quarterly')>
# <ShoppingTrends(customer_id=3881, age=42, gender='Female', item_purchased='Shirt', category='Clothing', purchase_amount_usd=20, location='Massachusetts', size='M', color='Red', season='Winter', review_rating=3.9, subscription_status='No', payment_method='Credit Card', shipping_type='Free Shipping', discount_applied='No', promo_code_used='No', previous_purchases=40, preferred_payment_method='PayPal', frequency_of_purchases='Monthly')>
# <ShoppingTrends(customer_id=3882, age=56, gender='Female', item_purchased='Scarf', category='Accessories', purchase_amount_usd=25, location='Georgia', size='L', color='Silver', season='Spring', review_rating=2.8, subscription_status='No', payment_method='PayPal', shipping_type='2-Day Shipping', discount_applied='No', promo_code_used='No', previous_purchases=17, preferred_payment_method='Debit Card', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=3883, age=35, gender='Female', item_purchased='Pants', category='Clothing', purchase_amount_usd=95, location='North Dakota', size='L', color='Blue', season='Fall', review_rating=2.6, subscription_status='No', payment_method='Credit Card', shipping_type='Free Shipping', discount_applied='No', promo_code_used='No', previous_purchases=24, preferred_payment_method='Cash', frequency_of_purchases='Fortnightly')>
# <ShoppingTrends(customer_id=3884, age=34, gender='Female', item_purchased='Hat', category='Accessories', purchase_amount_usd=38, location='North Dakota', size='XL', color='Purple', season='Fall', review_rating=4.0, subscription_status='No', payment_method='Bank Transfer', shipping_type='Next Day Air', discount_applied='No', promo_code_used='No', previous_purchases=22, preferred_payment_method='Cash', frequency_of_purchases='Fortnightly')>
# <ShoppingTrends(customer_id=3885, age=47, gender='Female', item_purchased='Sandals', category='Footwear', purchase_amount_usd=29, location='Maryland', size='M', color='Brown', season='Fall', review_rating=4.9, subscription_status='No', payment_method='Debit Card', shipping_type='Express', discount_applied='No', promo_code_used='No', previous_purchases=3, preferred_payment_method='PayPal', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=3886, age=49, gender='Female', item_purchased='Socks', category='Clothing', purchase_amount_usd=64, location='New Mexico', size='L', color='Purple', season='Winter', review_rating=3.2, subscription_status='No', payment_method='Venmo', shipping_type='Free Shipping', discount_applied='No', promo_code_used='No', previous_purchases=39, preferred_payment_method='Cash', frequency_of_purchases='Quarterly')>
# <ShoppingTrends(customer_id=3887, age=37, gender='Female', item_purchased='Jewelry', category='Accessories', purchase_amount_usd=92, location='Iowa', size='S', color='Brown', season='Summer', review_rating=3.9, subscription_status='No', payment_method='Bank Transfer', shipping_type='Express', discount_applied='No', promo_code_used='No', previous_purchases=40, preferred_payment_method='Debit Card', frequency_of_purchases='Quarterly')>
# <ShoppingTrends(customer_id=3888, age=40, gender='Female', item_purchased='Shirt', category='Clothing', purchase_amount_usd=34, location='Kansas', size='M', color='Charcoal', season='Spring', review_rating=2.7, subscription_status='No', payment_method='PayPal', shipping_type='Express', discount_applied='No', promo_code_used='No', previous_purchases=1, preferred_payment_method='Credit Card', frequency_of_purchases='Quarterly')>
# <ShoppingTrends(customer_id=3889, age=45, gender='Female', item_purchased='Sneakers', category='Footwear', purchase_amount_usd=69, location='Virginia', size='M', color='Violet', season='Spring', review_rating=3.4, subscription_status='No', payment_method='Bank Transfer', shipping_type='Standard', discount_applied='No', promo_code_used='No', previous_purchases=14, preferred_payment_method='Venmo', frequency_of_purchases='Bi-Weekly')>
# <ShoppingTrends(customer_id=3890, age=57, gender='Female', item_purchased='Dress', category='Clothing', purchase_amount_usd=65, location='Alaska', size='S', color='Yellow', season='Spring', review_rating=3.5, subscription_status='No', payment_method='Debit Card', shipping_type='Express', discount_applied='No', promo_code_used='No', previous_purchases=49, preferred_payment_method='Bank Transfer', frequency_of_purchases='Annually')>
# <ShoppingTrends(customer_id=3891, age=35, gender='Female', item_purchased='Shirt', category='Clothing', purchase_amount_usd=81, location='Nebraska', size='XL', color='Green', season='Winter', review_rating=2.6, subscription_status='No', payment_method='Credit Card', shipping_type='Standard', discount_applied='No', promo_code_used='No', previous_purchases=33, preferred_payment_method='Debit Card', frequency_of_purchases='Annually')>
# <ShoppingTrends(customer_id=3892, age=36, gender='Female', item_purchased='Dress', category='Clothing', purchase_amount_usd=30, location='Colorado', size='L', color='Peach', season='Winter', review_rating=4.7, subscription_status='No', payment_method='Cash', shipping_type='Free Shipping', discount_applied='No', promo_code_used='No', previous_purchases=6, preferred_payment_method='Bank Transfer', frequency_of_purchases='Quarterly')>
# <ShoppingTrends(customer_id=3893, age=35, gender='Female', item_purchased='Jewelry', category='Accessories', purchase_amount_usd=86, location='Michigan', size='L', color='Indigo', season='Summer', review_rating=3.5, subscription_status='No', payment_method='Bank Transfer', shipping_type='Standard', discount_applied='No', promo_code_used='No', previous_purchases=5, preferred_payment_method='PayPal', frequency_of_purchases='Fortnightly')>
# <ShoppingTrends(customer_id=3894, age=21, gender='Female', item_purchased='Hat', category='Accessories', purchase_amount_usd=64, location='Massachusetts', size='L', color='White', season='Fall', review_rating=3.3, subscription_status='No', payment_method='Bank Transfer', shipping_type='Store Pickup', discount_applied='No', promo_code_used='No', previous_purchases=29, preferred_payment_method='Bank Transfer', frequency_of_purchases='Bi-Weekly')>
# <ShoppingTrends(customer_id=3895, age=66, gender='Female', item_purchased='Skirt', category='Clothing', purchase_amount_usd=78, location='Connecticut', size='L', color='White', season='Spring', review_rating=3.9, subscription_status='No', payment_method='Cash', shipping_type='2-Day Shipping', discount_applied='No', promo_code_used='No', previous_purchases=44, preferred_payment_method='Credit Card', frequency_of_purchases='Every 3 Months')>
# <ShoppingTrends(customer_id=3896, age=40, gender='Female', item_purchased='Hoodie', category='Clothing', purchase_amount_usd=28, location='Virginia', size='L', color='Turquoise', season='Summer', review_rating=4.2, subscription_status='No', payment_method='Cash', shipping_type='2-Day Shipping', discount_applied='No', promo_code_used='No', previous_purchases=32, preferred_payment_method='Venmo', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=3897, age=52, gender='Female', item_purchased='Backpack', category='Accessories', purchase_amount_usd=49, location='Iowa', size='L', color='White', season='Spring', review_rating=4.5, subscription_status='No', payment_method='PayPal', shipping_type='Store Pickup', discount_applied='No', promo_code_used='No', previous_purchases=41, preferred_payment_method='Bank Transfer', frequency_of_purchases='Bi-Weekly')>
# <ShoppingTrends(customer_id=3898, age=46, gender='Female', item_purchased='Belt', category='Accessories', purchase_amount_usd=33, location='New Jersey', size='L', color='Green', season='Spring', review_rating=2.9, subscription_status='No', payment_method='Credit Card', shipping_type='Standard', discount_applied='No', promo_code_used='No', previous_purchases=24, preferred_payment_method='Venmo', frequency_of_purchases='Quarterly')>
# <ShoppingTrends(customer_id=3899, age=44, gender='Female', item_purchased='Shoes', category='Footwear', purchase_amount_usd=77, location='Minnesota', size='S', color='Brown', season='Summer', review_rating=3.8, subscription_status='No', payment_method='PayPal', shipping_type='Express', discount_applied='No', promo_code_used='No', previous_purchases=24, preferred_payment_method='Venmo', frequency_of_purchases='Weekly')>
# <ShoppingTrends(customer_id=3900, age=52, gender='Female', item_purchased='Handbag', category='Accessories', purchase_amount_usd=81, location='California', size='M', color='Beige', season='Spring', review_rating=3.1, subscription_status='No', payment_method='Bank Transfer', shipping_type='Store Pickup', discount_applied='No', promo_code_used='No', previous_purchases=33, preferred_payment_method='Venmo', frequency_of_purchases='Quarterly')>
# <ShoppingTrends(customer_id=3901, age=25, gender='Male', item_purchased='Shirt', category='Clothing', purchase_amount_usd=100, location='Oregon', size='L', color='White', season='Winter', review_rating=4.0, subscription_status='Yes', payment_method='PayPal', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=5, preferred_payment_method='Credit Card', frequency_of_purchases='Quarterly')>
# <ShoppingTrends(customer_id=0, age=40, gender='None', item_purchased='Shirt', category='Clothing', purchase_amount_usd=50, location='Oregon', size='M', color='White', season='Summer', review_rating=2.0, subscription_status='No', payment_method='PayPal', shipping_type='Free Shipping', discount_applied='Yes', promo_code_used='Yes', previous_purchases=5, preferred_payment_method='Credit Card', frequency_of_purchases='Quarterly')>

# %%
# find rows with NULL Customer ID
null_ids = session.query(ShoppingTrends).filter(ShoppingTrends.customer_id.is_(None)).all()
if null_ids:
    print("Rows with NULL Customer ID:")
    for row in null_ids:
        print(row)
else:
    print("No rows found with NULL Customer ID.\n")


total_rows = session.query(ShoppingTrends).count()
print(f"Total rows in the table: {total_rows}\n")

non_null_ids = session.query(ShoppingTrends).filter(ShoppingTrends.customer_id.isnot(None)).all()
print(f"Rows with non-NULL Customer ID: {len(non_null_ids)}")
# Out:
# 2025-03-14 15:25:42,398 INFO sqlalchemy.engine.Engine SELECT shopping_trends.`Customer ID` AS `shopping_trends_Customer ID`, shopping_trends.`Age` AS `shopping_trends_Age`, shopping_trends.`Gender` AS `shopping_trends_Gender`, shopping_trends.`Item Purchased` AS `shopping_trends_Item Purchased`, shopping_trends.`Category` AS `shopping_trends_Category`, shopping_trends.`Purchase Amount (USD)` AS `shopping_trends_Purchase Amount (USD)`, shopping_trends.`Location` AS `shopping_trends_Location`, shopping_trends.`Size` AS `shopping_trends_Size`, shopping_trends.`Color` AS `shopping_trends_Color`, shopping_trends.`Season` AS `shopping_trends_Season`, shopping_trends.`Review Rating` AS `shopping_trends_Review Rating`, shopping_trends.`Subscription Status` AS `shopping_trends_Subscription Status`, shopping_trends.`Payment Method` AS `shopping_trends_Payment Method`, shopping_trends.`Shipping Type` AS `shopping_trends_Shipping Type`, shopping_trends.`Discount Applied` AS `shopping_trends_Discount Applied`, shopping_trends.`Promo Code Used` AS `shopping_trends_Promo Code Used`, shopping_trends.`Previous Purchases` AS `shopping_trends_Previous Purchases`, shopping_trends.`Preferred Payment Method` AS `shopping_trends_Preferred Payment Method`, shopping_trends.`Frequency of Purchases` AS `shopping_trends_Frequency of Purchases`
# FROM shopping_trends
# WHERE shopping_trends.`Customer ID` IS NULL
# 2025-03-14 15:25:42,399 INFO sqlalchemy.engine.Engine [cached since 0.8286s ago] {}
# No rows found with NULL Customer ID.
#
# 2025-03-14 15:25:42,422 INFO sqlalchemy.engine.Engine SELECT count(*) AS count_1
# FROM (SELECT shopping_trends.`Customer ID` AS `shopping_trends_Customer ID`, shopping_trends.`Age` AS `shopping_trends_Age`, shopping_trends.`Gender` AS `shopping_trends_Gender`, shopping_trends.`Item Purchased` AS `shopping_trends_Item Purchased`, shopping_trends.`Category` AS `shopping_trends_Category`, shopping_trends.`Purchase Amount (USD)` AS `shopping_trends_Purchase Amount (USD)`, shopping_trends.`Location` AS `shopping_trends_Location`, shopping_trends.`Size` AS `shopping_trends_Size`, shopping_trends.`Color` AS `shopping_trends_Color`, shopping_trends.`Season` AS `shopping_trends_Season`, shopping_trends.`Review Rating` AS `shopping_trends_Review Rating`, shopping_trends.`Subscription Status` AS `shopping_trends_Subscription Status`, shopping_trends.`Payment Method` AS `shopping_trends_Payment Method`, shopping_trends.`Shipping Type` AS `shopping_trends_Shipping Type`, shopping_trends.`Discount Applied` AS `shopping_trends_Discount Applied`, shopping_trends.`Promo Code Used` AS `shopping_trends_Promo Code Used`, shopping_trends.`Previous Purchases` AS `shopping_trends_Previous Purchases`, shopping_trends.`Preferred Payment Method` AS `shopping_trends_Preferred Payment Method`, shopping_trends.`Frequency of Purchases` AS `shopping_trends_Frequency of Purchases`
# FROM shopping_trends) AS anon_1
# 2025-03-14 15:25:42,423 INFO sqlalchemy.engine.Engine [generated in 0.00108s] {}
# Total rows in the table: 3902
#
# 2025-03-14 15:25:42,434 INFO sqlalchemy.engine.Engine SELECT shopping_trends.`Customer ID` AS `shopping_trends_Customer ID`, shopping_trends.`Age` AS `shopping_trends_Age`, shopping_trends.`Gender` AS `shopping_trends_Gender`, shopping_trends.`Item Purchased` AS `shopping_trends_Item Purchased`, shopping_trends.`Category` AS `shopping_trends_Category`, shopping_trends.`Purchase Amount (USD)` AS `shopping_trends_Purchase Amount (USD)`, shopping_trends.`Location` AS `shopping_trends_Location`, shopping_trends.`Size` AS `shopping_trends_Size`, shopping_trends.`Color` AS `shopping_trends_Color`, shopping_trends.`Season` AS `shopping_trends_Season`, shopping_trends.`Review Rating` AS `shopping_trends_Review Rating`, shopping_trends.`Subscription Status` AS `shopping_trends_Subscription Status`, shopping_trends.`Payment Method` AS `shopping_trends_Payment Method`, shopping_trends.`Shipping Type` AS `shopping_trends_Shipping Type`, shopping_trends.`Discount Applied` AS `shopping_trends_Discount Applied`, shopping_trends.`Promo Code Used` AS `shopping_trends_Promo Code Used`, shopping_trends.`Previous Purchases` AS `shopping_trends_Previous Purchases`, shopping_trends.`Preferred Payment Method` AS `shopping_trends_Preferred Payment Method`, shopping_trends.`Frequency of Purchases` AS `shopping_trends_Frequency of Purchases`
# FROM shopping_trends
# WHERE shopping_trends.`Customer ID` IS NOT NULL
# 2025-03-14 15:25:42,435 INFO sqlalchemy.engine.Engine [generated in 0.00104s] {}
# Rows with non-NULL Customer ID: 3902

# %%
#select customer_id, age, gender, item_purchased, size, subscription_status, frequency_of_purchases from shooping_trends where color ==like'%white%' and age <= 35 order by customer_id
color = session.query(ShoppingTrends).filter(ShoppingTrends.color == 'White', ShoppingTrends.age <= 35).order_by(ShoppingTrends.customer_id).all()
for row in color:
    if row is not None:
        print(row.customer_id, row.age, row.gender, row.item_purchased, row.size, row.subscription_status, row.frequency_of_purchases)
    else:
        print("Encountered a None row.")
# Out:
# 2025-03-14 15:25:42,710 INFO sqlalchemy.engine.Engine SELECT shopping_trends.`Customer ID` AS `shopping_trends_Customer ID`, shopping_trends.`Age` AS `shopping_trends_Age`, shopping_trends.`Gender` AS `shopping_trends_Gender`, shopping_trends.`Item Purchased` AS `shopping_trends_Item Purchased`, shopping_trends.`Category` AS `shopping_trends_Category`, shopping_trends.`Purchase Amount (USD)` AS `shopping_trends_Purchase Amount (USD)`, shopping_trends.`Location` AS `shopping_trends_Location`, shopping_trends.`Size` AS `shopping_trends_Size`, shopping_trends.`Color` AS `shopping_trends_Color`, shopping_trends.`Season` AS `shopping_trends_Season`, shopping_trends.`Review Rating` AS `shopping_trends_Review Rating`, shopping_trends.`Subscription Status` AS `shopping_trends_Subscription Status`, shopping_trends.`Payment Method` AS `shopping_trends_Payment Method`, shopping_trends.`Shipping Type` AS `shopping_trends_Shipping Type`, shopping_trends.`Discount Applied` AS `shopping_trends_Discount Applied`, shopping_trends.`Promo Code Used` AS `shopping_trends_Promo Code Used`, shopping_trends.`Previous Purchases` AS `shopping_trends_Previous Purchases`, shopping_trends.`Preferred Payment Method` AS `shopping_trends_Preferred Payment Method`, shopping_trends.`Frequency of Purchases` AS `shopping_trends_Frequency of Purchases`
# FROM shopping_trends
# WHERE shopping_trends.`Color` = %(Color_1)s AND shopping_trends.`Age` <= %(Age_1)s ORDER BY shopping_trends.`Customer ID`
# 2025-03-14 15:25:42,712 INFO sqlalchemy.engine.Engine [generated in 0.00156s] {'Color_1': 'White', 'Age_1': 35}
# 24 31 Male Pants XL Yes Weekly
# 58 21 Male Coat M Yes Fortnightly
# 102 27 Male Coat XL Yes Bi-Weekly
# 229 18 Male Socks M Yes Annually
# 307 26 Male Jacket S Yes Annually
# 374 23 Male Coat L Yes Bi-Weekly
# 409 34 Male Sneakers L Yes Fortnightly
# 484 23 Male Hoodie M Yes Weekly
# 558 18 Male Shirt M Yes Weekly
# 597 23 Male Shoes XL Yes Annually
# 624 19 Male Shoes M Yes Bi-Weekly
# 703 18 Male Shirt M Yes Weekly
# 992 20 Male Shorts XL Yes Bi-Weekly
# 1141 31 Male Jeans M No Every 3 Months
# 1164 26 Male Pants L No Monthly
# 1196 25 Male Scarf M No Monthly
# 1281 30 Male Pants L No Every 3 Months
# 1510 20 Male Dress XL No Annually
# 1522 29 Male Backpack M No Weekly
# 1605 18 Male Sweater M No Every 3 Months
# 1633 35 Male Gloves S No Every 3 Months
# 1751 31 Male Sunglasses M No Every 3 Months
# 1815 32 Male Jeans M No Quarterly
# 1818 32 Male T-shirt M No Weekly
# 1830 30 Male Hat M No Quarterly
# 1991 32 Male Backpack L No Annually
# 2222 25 Male Shorts XL No Annually
# 2324 35 Male Gloves L No Monthly
# 2431 20 Male Jacket XL No Quarterly
# 2868 21 Female Sneakers L No Fortnightly
# 2930 31 Female Socks XL No Fortnightly
# 2937 31 Female Skirt M No Weekly
# 2938 28 Female Handbag M No Weekly
# 2971 24 Female Jewelry M No Bi-Weekly
# 3170 35 Female T-shirt M No Weekly
# 3228 28 Female Scarf XL No Quarterly
# 3339 29 Female Skirt L No Monthly
# 3406 28 Female Blouse M No Bi-Weekly
# 3473 31 Female Blouse S No Weekly
# 3484 19 Female Hoodie L No Every 3 Months
# 3517 34 Female Boots S No Bi-Weekly
# 3520 31 Female Shorts M No Fortnightly
# 3649 31 Female Skirt M No Bi-Weekly
# 3671 31 Female Shoes S No Every 3 Months
# 3894 21 Female Hat L No Bi-Weekly
# 3901 25 Male Shirt L Yes Quarterly

# %%
#1
pd.read_sql("SELECT * FROM shopping_trends where category like '%%Clothing%%'", engine)
#2
query = "SELECT * FROM shopping_trends WHERE category LIKE %s"
params = ('%Clothing%',)  # Tuple with wildcards included
pd.read_sql(query, engine, params=params)
# Out:
# 2025-03-14 15:25:42,748 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-14 15:25:42,749 INFO sqlalchemy.engine.Engine DESCRIBE `consumer_analysis`.`SELECT * FROM shopping_trends where category like '%%%%Clothing%%%%'`
# 2025-03-14 15:25:42,750 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-14 15:25:42,755 INFO sqlalchemy.engine.Engine SELECT * FROM shopping_trends where category like '%%Clothing%%'
# 2025-03-14 15:25:42,756 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-14 15:25:42,843 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-03-14 15:25:42,846 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-14 15:25:42,847 INFO sqlalchemy.engine.Engine DESCRIBE `consumer_analysis`.`SELECT * FROM shopping_trends WHERE category LIKE %%s`
# 2025-03-14 15:25:42,848 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-14 15:25:42,851 INFO sqlalchemy.engine.Engine SELECT * FROM shopping_trends WHERE category LIKE %s
# 2025-03-14 15:25:42,851 INFO sqlalchemy.engine.Engine [raw sql] ('%Clothing%',)
# 2025-03-14 15:25:42,947 INFO sqlalchemy.engine.Engine ROLLBACK
#       Customer ID  Age  Gender Item Purchased  Category  \
# 0               1   55    Male         Blouse  Clothing
# 1               2   19    Male        Sweater  Clothing
# 2               3   50    Male          Jeans  Clothing
# 3               5   45    Male         Blouse  Clothing
# 4               7   63    Male          Shirt  Clothing
# ...           ...  ...     ...            ...       ...
# 1734         3892   36  Female          Dress  Clothing
# 1735         3895   66  Female          Skirt  Clothing
# 1736         3896   40  Female         Hoodie  Clothing
# 1737         3901   25    Male          Shirt  Clothing
# 1738            0   40    None          Shirt  Clothing
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# 2                        73  Massachusetts    S     Maroon  Spring
# 3                        49         Oregon    M  Turquoise  Spring
# 4                        85        Montana    M       Gray    Fall
# ...                     ...            ...  ...        ...     ...
# 1734                     30       Colorado    L      Peach  Winter
# 1735                     78    Connecticut    L      White  Spring
# 1736                     28       Virginia    L  Turquoise  Summer
# 1737                    100         Oregon    L      White  Winter
# 1738                     50         Oregon    M      White  Summer
#
#       Review Rating Subscription Status Payment Method   Shipping Type  \
# 0               3.1                 Yes    Credit Card         Express
# 1               3.1                 Yes  Bank Transfer         Express
# 2               3.1                 Yes           Cash   Free Shipping
# 3               2.7                 Yes           Cash   Free Shipping
# 4               3.2                 Yes     Debit Card   Free Shipping
# ...             ...                 ...            ...             ...
# 1734            4.7                  No           Cash   Free Shipping
# 1735            3.9                  No           Cash  2-Day Shipping
# 1736            4.2                  No           Cash  2-Day Shipping
# 1737            4.0                 Yes         PayPal   Free Shipping
# 1738            2.0                  No         PayPal   Free Shipping
#
#      Discount Applied Promo Code Used  Previous Purchases  \
# 0                 Yes             Yes                  14
# 1                 Yes             Yes                   2
# 2                 Yes             Yes                  23
# 3                 Yes             Yes                  31
# 4                 Yes             Yes                  49
# ...               ...             ...                 ...
# 1734               No              No                   6
# 1735               No              No                  44
# 1736               No              No                  32
# 1737              Yes             Yes                   5
# 1738              Yes             Yes                   5
#
#      Preferred Payment Method Frequency of Purchases
# 0                       Venmo            Fortnightly
# 1                        Cash            Fortnightly
# 2                 Credit Card                 Weekly
# 3                      PayPal               Annually
# 4                        Cash              Quarterly
# ...                       ...                    ...
# 1734            Bank Transfer              Quarterly
# 1735              Credit Card         Every 3 Months
# 1736                    Venmo                 Weekly
# 1737              Credit Card              Quarterly
# 1738              Credit Card              Quarterly
#
# [1739 rows x 19 columns]

# %%
#get all columns from the table after updating rows:
df_a = update_df()
df_a
# Out:
# 2025-03-14 15:25:42,999 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-14 15:25:43,001 INFO sqlalchemy.engine.Engine DESCRIBE `consumer_analysis`.`shopping_trends`
# 2025-03-14 15:25:43,001 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-14 15:25:43,007 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `consumer_analysis`
# 2025-03-14 15:25:43,008 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-14 15:25:43,011 INFO sqlalchemy.engine.Engine SHOW FULL TABLES FROM `consumer_analysis`
# 2025-03-14 15:25:43,012 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-14 15:25:43,015 INFO sqlalchemy.engine.Engine SHOW CREATE TABLE `shopping_trends`
# 2025-03-14 15:25:43,016 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-03-14 15:25:43,023 INFO sqlalchemy.engine.Engine SELECT shopping_trends.`Customer ID`, shopping_trends.`Age`, shopping_trends.`Gender`, shopping_trends.`Item Purchased`, shopping_trends.`Category`, shopping_trends.`Purchase Amount (USD)`, shopping_trends.`Location`, shopping_trends.`Size`, shopping_trends.`Color`, shopping_trends.`Season`, shopping_trends.`Review Rating`, shopping_trends.`Subscription Status`, shopping_trends.`Payment Method`, shopping_trends.`Shipping Type`, shopping_trends.`Discount Applied`, shopping_trends.`Promo Code Used`, shopping_trends.`Previous Purchases`, shopping_trends.`Preferred Payment Method`, shopping_trends.`Frequency of Purchases`
# FROM shopping_trends
# 2025-03-14 15:25:43,024 INFO sqlalchemy.engine.Engine [generated in 0.00117s] {}
# 2025-03-14 15:25:43,258 INFO sqlalchemy.engine.Engine ROLLBACK
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
# 3900         3901   25    Male          Shirt     Clothing
# 3901            0   40    None          Shirt     Clothing
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# 2                        73  Massachusetts    S     Maroon  Spring
# 3                        90   Rhode Island    M     Maroon  Spring
# 4                        49         Oregon    M  Turquoise  Spring
# ...                     ...            ...  ...        ...     ...
# 3897                     33     New Jersey    L      Green  Spring
# 3898                     77      Minnesota    S      Brown  Summer
# 3899                     81     California    M      Beige  Spring
# 3900                    100         Oregon    L      White  Winter
# 3901                     50         Oregon    M      White  Summer
#
#       Review Rating Subscription Status Payment Method  Shipping Type  \
# 0               3.1                 Yes    Credit Card        Express
# 1               3.1                 Yes  Bank Transfer        Express
# 2               3.1                 Yes           Cash  Free Shipping
# 3               3.5                 Yes         PayPal   Next Day Air
# 4               2.7                 Yes           Cash  Free Shipping
# ...             ...                 ...            ...            ...
# 3897            2.9                  No    Credit Card       Standard
# 3898            3.8                  No         PayPal        Express
# 3899            3.1                  No  Bank Transfer   Store Pickup
# 3900            4.0                 Yes         PayPal  Free Shipping
# 3901            2.0                  No         PayPal  Free Shipping
#
#      Discount Applied Promo Code Used  Previous Purchases  \
# 0                 Yes             Yes                  14
# 1                 Yes             Yes                   2
# 2                 Yes             Yes                  23
# 3                 Yes             Yes                  49
# 4                 Yes             Yes                  31
# ...               ...             ...                 ...
# 3897               No              No                  24
# 3898               No              No                  24
# 3899               No              No                  33
# 3900              Yes             Yes                   5
# 3901              Yes             Yes                   5
#
#      Preferred Payment Method Frequency of Purchases
# 0                       Venmo            Fortnightly
# 1                        Cash            Fortnightly
# 2                 Credit Card                 Weekly
# 3                      PayPal                 Weekly
# 4                      PayPal               Annually
# ...                       ...                    ...
# 3897                    Venmo              Quarterly
# 3898                    Venmo                 Weekly
# 3899                    Venmo              Quarterly
# 3900              Credit Card              Quarterly
# 3901              Credit Card              Quarterly
#
# [3902 rows x 19 columns]

# %%
#get selected columns from the table

Session = sessionmaker(bind = engine)
session = Session()
query = (select(
    ShoppingTrends.age,
    ShoppingTrends.gender,
    ShoppingTrends.category,
    ShoppingTrends.purchase_amount_usd,
    ShoppingTrends.location,
    ShoppingTrends.size,
    ShoppingTrends.color,
    ShoppingTrends.season,
    ShoppingTrends.review_rating,
    ShoppingTrends.subscription_status,
    ShoppingTrends.payment_method,
    ShoppingTrends.shipping_type,
    ShoppingTrends.discount_applied,
    ShoppingTrends.previous_purchases,
    ShoppingTrends.frequency_of_purchases
))

with engine.connect() as connection:
    result = connection.execute(query)
    df = pd.DataFrame(result.fetchall(), columns = result.keys())


'''
import pandas as pd
from sqlalchemy.orm import sessionmaker
from sqlalchemy import select

# Assuming ShoppingTrends is your ORM mapped class
Session = sessionmaker(bind=engine)
session = Session()


query = (select(ShoppingTrends))

with engine.connect() as connection:
    result = connection.execute(query)
    df_a = pd.DataFrame(result.fetchall(), columns = result.keys())
'''
# Out:
# 2025-03-14 15:25:43,291 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-03-14 15:25:43,292 INFO sqlalchemy.engine.Engine SELECT shopping_trends.`Age`, shopping_trends.`Gender`, shopping_trends.`Category`, shopping_trends.`Purchase Amount (USD)`, shopping_trends.`Location`, shopping_trends.`Size`, shopping_trends.`Color`, shopping_trends.`Season`, shopping_trends.`Review Rating`, shopping_trends.`Subscription Status`, shopping_trends.`Payment Method`, shopping_trends.`Shipping Type`, shopping_trends.`Discount Applied`, shopping_trends.`Previous Purchases`, shopping_trends.`Frequency of Purchases`
# FROM shopping_trends
# 2025-03-14 15:25:43,294 INFO sqlalchemy.engine.Engine [generated in 0.00257s] {}
# 2025-03-14 15:25:43,501 INFO sqlalchemy.engine.Engine ROLLBACK
# '\nimport pandas as pd\nfrom sqlalchemy.orm import sessionmaker\nfrom sqlalchemy import select\n\n# Assuming ShoppingTrends is your ORM mapped class\nSession = sessionmaker(bind=engine)\nsession = Session()\n\n\nquery = (select(ShoppingTrends))\n\nwith engine.connect() as connection:\n    result = connection.execute(query)\n    df_a = pd.DataFrame(result.fetchall(), columns = result.keys())\n'

# %%
#handle null 
df.loc[df['Gender'].isna(), 'Gender'] = 'Prefer not to say'

df
# Out:
#       Age             Gender     Category  Purchase Amount (USD)  \
# 0      55               Male     Clothing                     53
# 1      19               Male     Clothing                     64
# 2      50               Male     Clothing                     73
# 3      21               Male     Footwear                     90
# 4      45               Male     Clothing                     49
# ...   ...                ...          ...                    ...
# 3897   46             Female  Accessories                     33
# 3898   44             Female     Footwear                     77
# 3899   52             Female  Accessories                     81
# 3900   25               Male     Clothing                    100
# 3901   40  Prefer not to say     Clothing                     50
#
#            Location Size      Color  Season  Review Rating  \
# 0          Kentucky    L       Gray  Winter            3.1
# 1             Maine    L     Maroon  Winter            3.1
# 2     Massachusetts    S     Maroon  Spring            3.1
# 3      Rhode Island    M     Maroon  Spring            3.5
# 4            Oregon    M  Turquoise  Spring            2.7
# ...             ...  ...        ...     ...            ...
# 3897     New Jersey    L      Green  Spring            2.9
# 3898      Minnesota    S      Brown  Summer            3.8
# 3899     California    M      Beige  Spring            3.1
# 3900         Oregon    L      White  Winter            4.0
# 3901         Oregon    M      White  Summer            2.0
#
#      Subscription Status Payment Method  Shipping Type Discount Applied  \
# 0                    Yes    Credit Card        Express              Yes
# 1                    Yes  Bank Transfer        Express              Yes
# 2                    Yes           Cash  Free Shipping              Yes
# 3                    Yes         PayPal   Next Day Air              Yes
# 4                    Yes           Cash  Free Shipping              Yes
# ...                  ...            ...            ...              ...
# 3897                  No    Credit Card       Standard               No
# 3898                  No         PayPal        Express               No
# 3899                  No  Bank Transfer   Store Pickup               No
# 3900                 Yes         PayPal  Free Shipping              Yes
# 3901                  No         PayPal  Free Shipping              Yes
#
#       Previous Purchases Frequency of Purchases
# 0                     14            Fortnightly
# 1                      2            Fortnightly
# 2                     23                 Weekly
# 3                     49                 Weekly
# 4                     31               Annually
# ...                  ...                    ...
# 3897                  24              Quarterly
# 3898                  24                 Weekly
# 3899                  33              Quarterly
# 3900                   5              Quarterly
# 3901                   5              Quarterly
#
# [3902 rows x 15 columns]

# %%
#gender purchase frequency distribution
gen_freq_dis = df.groupby('Gender')['Frequency of Purchases'].value_counts().reset_index(name = 'count')
female = gen_freq_dis[gen_freq_dis['Gender'] =='Female']
male = gen_freq_dis[gen_freq_dis['Gender'] =='Male']


gen_freq = female.merge(male, on = 'Frequency of Purchases', how ='left', suffixes=('_female', '_male'))

gen_freq


#subscription status
sub_acct = df[df['Subscription Status'] == 'Yes']

sub_acct = sub_acct[['Gender','Frequency of Purchases','Subscription Status']]

female_subscription = len(sub_acct[sub_acct['Gender'] == 'Female'])
male_subscription = len(sub_acct) - female_subscription
print(f'Frmale subscription: {female_subscription}\nMale subscription: {male_subscription}')

subscription_rate = len(sub_acct) / len(df)
print(f'Total subscription rate: {subscription_rate}') 


cnt = sub_acct.groupby(['Gender','Frequency of Purchases'])['Subscription Status'].count().reset_index(name = 'Male subcription status')

gen_freq = gen_freq.merge(cnt, on = 'Frequency of Purchases', how = 'left')

gen_freq['total_counts'] = gen_freq['count_female'] + gen_freq['count_male']
gen_freq['subscription_rate_male'] = (gen_freq['Male subcription status'] / gen_freq['count_male']).round(2)
gen_freq['subscription_rate_total'] = (gen_freq['Male subcription status'] / gen_freq['total_counts']).round(2)
gen_freq

cleaned_gen_freq = gen_freq[['Frequency of Purchases','count_female','count_male','Male subcription status','subscription_rate_male','total_counts','subscription_rate_total']]


gen_pur_power = df.groupby(['Gender','Frequency of Purchases'])['Purchase Amount (USD)'].sum().reset_index()
female = gen_pur_power[gen_pur_power['Gender'] =='Female']
male = gen_pur_power[gen_pur_power['Gender'] =='Male']

male.rename(columns = {'Purchase Amount (USD)': 'Purchase Amount (USD) Male'}, inplace = True)


gen_pur_power = male.merge(female[['Frequency of Purchases', 'Purchase Amount (USD)']], 
                  on='Frequency of Purchases', 
                  how='left', 
                  suffixes=('', ' Female'))

gen_pur_power.rename(columns={'Purchase Amount (USD)': 'Purchase Amount (USD) Female'}, inplace = True)
gen_pur_power.drop(columns = ['Gender'], inplace =True)

gender_summary = gen_pur_power.merge(cleaned_gen_freq, on = 'Frequency of Purchases', how = 'left')
gender_summary
# Out:
# Frmale subscription: 0
# Male subscription: 1054
# Total subscription rate: 0.27011788826242955
# C:\Users\hosin\AppData\Local\Temp\ipykernel_13216\2627477568.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   male.rename(columns = {'Purchase Amount (USD)': 'Purchase Amount (USD) Male'}, inplace = True)
#   Frequency of Purchases  Purchase Amount (USD) Male  \
# 0               Annually                       23283
# 1              Bi-Weekly                       21936
# 2         Every 3 Months                       23526
# 3            Fortnightly                       22370
# 4                Monthly                       21722
# 5              Quarterly                       23403
# 6                 Weekly                       21750
#
#    Purchase Amount (USD) Female  count_female  count_male  \
# 0                         11136           185         387
# 1                         11264           188         359
# 2                         11562           186         398
# 3                          9637           163         379
# 4                         11088           185         368
# 5                         10468           169         395
# 6                         10036           172         367
#
#    Male subcription status  subscription_rate_male  total_counts  \
# 0                      160                    0.41           572
# 1                      140                    0.39           547
# 2                      154                    0.39           584
# 3                      153                    0.40           542
# 4                      149                    0.40           553
# 5                      141                    0.36           564
# 6                      157                    0.43           539
#
#    subscription_rate_total
# 0                     0.28
# 1                     0.26
# 2                     0.26
# 3                     0.28
# 4                     0.27
# 5                     0.25
# 6                     0.29

# %%
#location analysis 
location = df.groupby('Location').agg({'Purchase Amount (USD)':'sum',                                       
                                       'Review Rating':'mean',
                                       'Previous Purchases': 'mean',}).reset_index().sort_values(by = 'Purchase Amount (USD)', ascending = False)
location

more_than_5000 = location.loc[location['Purchase Amount (USD)'] >= 5000, 'Location']
more_than_5000

filtered = df[df['Location'].isin(more_than_5000)][['Location', 'Gender', 'Category', 'Purchase Amount (USD)', 'Color', 'Season']]

location_seasons_sales = filtered.groupby(['Location','Season'])['Purchase Amount (USD)'].sum().reset_index()
location_genders_sales = filtered.groupby(['Location','Gender'])['Purchase Amount (USD)'].sum().reset_index()
location_categories_sales = filtered.groupby(['Location','Category'])['Purchase Amount (USD)'].sum().reset_index()
total_location_sales = filtered.groupby('Location')['Purchase Amount (USD)'].sum().reset_index()

location_seasons_sales['rnk'] = location_seasons_sales.groupby('Location')['Purchase Amount (USD)'].rank(method='dense', ascending=False)
location_genders_sales['rnk'] = location_genders_sales.groupby('Location')['Purchase Amount (USD)'].rank(method='dense', ascending=False)
location_categories_sales['rnk'] = location_categories_sales.groupby('Location')['Purchase Amount (USD)'].rank(method='dense', ascending=False)

season = location_seasons_sales.loc[location_seasons_sales['rnk'] ==1]
gender = location_genders_sales.loc[location_genders_sales['rnk'] ==1]
category = location_categories_sales.loc[location_categories_sales['rnk'] ==1]



season.rename(columns = {'Purchase Amount (USD)': 'Season Purchase Amount (USD)'}, inplace = True)
gender.rename(columns = {'Purchase Amount (USD)': 'Gender Purchase Amount (USD)'}, inplace = True)
category.rename(columns = {'Purchase Amount (USD)': 'Category Purchase Amount (USD)'}, inplace = True)

top_performance_in_each_location = season.merge(gender[['Gender','Location','Gender Purchase Amount (USD)']], on = 'Location', how = 'left')
top_performance_in_each_location.drop(columns=['rnk'], inplace=True)

top_performance_in_each_location = top_performance_in_each_location.merge(category[['Category','Location','Category Purchase Amount (USD)']], on = 'Location', how = 'left')
top_performance_in_each_location = top_performance_in_each_location.merge(total_location_sales, on = 'Location',how = 'left')

top_performance_in_each_location.rename(columns={'Purchase Amount (USD)': 'Total Purchase Amount (USD) '}, inplace = True)
top_performance_in_each_location
# Out:
# C:\Users\hosin\AppData\Local\Temp\ipykernel_13216\1467567747.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   season.rename(columns = {'Purchase Amount (USD)': 'Season Purchase Amount (USD)'}, inplace = True)
# C:\Users\hosin\AppData\Local\Temp\ipykernel_13216\1467567747.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gender.rename(columns = {'Purchase Amount (USD)': 'Gender Purchase Amount (USD)'}, inplace = True)
# C:\Users\hosin\AppData\Local\Temp\ipykernel_13216\1467567747.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   category.rename(columns = {'Purchase Amount (USD)': 'Category Purchase Amount (USD)'}, inplace = True)
#          Location  Season  Season Purchase Amount (USD) Gender  \
# 0         Alabama  Summer                          1610   Male
# 1      California    Fall                          1659   Male
# 2           Idaho    Fall                          1622   Male
# 3        Illinois  Spring                          1620   Male
# 4         Montana  Winter                          1631   Male
# 5        Nebraska    Fall                          1389   Male
# 6          Nevada  Spring                          1916   Male
# 7      New Mexico    Fall                          1360   Male
# 8        New York    Fall                          1576   Male
# 9    North Dakota  Summer                          1656   Male
# 10  West Virginia    Fall                          1455   Male
#
#     Gender Purchase Amount (USD)     Category  Category Purchase Amount (USD)  \
# 0                           3583     Clothing                            2334
# 1                           3869     Clothing                            2740
# 2                           3715     Clothing                            2472
# 3                           3698     Clothing                            2508
# 4                           3600     Clothing                            2768
# 5                           3377  Accessories                            2147
# 6                           3642     Clothing                            2515
# 7                           3668     Clothing                            1925
# 8                           3674     Clothing                            2254
# 9                           3671     Clothing                            2206
# 10                          3935  Accessories                            1907
#
#     Total Purchase Amount (USD)
# 0                           5261
# 1                           5605
# 2                           5587
# 3                           5617
# 4                           5784
# 5                           5172
# 6                           5514
# 7                           5014
# 8                           5257
# 9                           5220
# 10                          5174

# %% [markdown]
# ### 5. **Subscription and Retention Analysis**
#    - **Analysis**: Explore the impact of subscription status on purchase frequency and amount. Compare subscribers vs. non-subscribers.
#    - **Objective**: Identify the benefits of subscription models and improve retention strategies.

# %%
df.head()
frequency_mapping = {
    'Fortnightly': 26,
    'Bi-Weekly': 26,
    'Weekly': 52,
    'Monthly': 12,
    'Quarterly': 4,
    'Every 3 Months': 4,
    'Annually': 1
}
 

df['Expected yearly purchase frequency'] = df['Frequency of Purchases'].replace(frequency_mapping)
df
# Out:
# C:\Users\hosin\AppData\Local\Temp\ipykernel_13216\369915847.py:13: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Expected yearly purchase frequency'] = df['Frequency of Purchases'].replace(frequency_mapping)
#       Age             Gender     Category  Purchase Amount (USD)  \
# 0      55               Male     Clothing                     53
# 1      19               Male     Clothing                     64
# 2      50               Male     Clothing                     73
# 3      21               Male     Footwear                     90
# 4      45               Male     Clothing                     49
# ...   ...                ...          ...                    ...
# 3897   46             Female  Accessories                     33
# 3898   44             Female     Footwear                     77
# 3899   52             Female  Accessories                     81
# 3900   25               Male     Clothing                    100
# 3901   40  Prefer not to say     Clothing                     50
#
#            Location Size      Color  Season  Review Rating  \
# 0          Kentucky    L       Gray  Winter            3.1
# 1             Maine    L     Maroon  Winter            3.1
# 2     Massachusetts    S     Maroon  Spring            3.1
# 3      Rhode Island    M     Maroon  Spring            3.5
# 4            Oregon    M  Turquoise  Spring            2.7
# ...             ...  ...        ...     ...            ...
# 3897     New Jersey    L      Green  Spring            2.9
# 3898      Minnesota    S      Brown  Summer            3.8
# 3899     California    M      Beige  Spring            3.1
# 3900         Oregon    L      White  Winter            4.0
# 3901         Oregon    M      White  Summer            2.0
#
#      Subscription Status Payment Method  Shipping Type Discount Applied  \
# 0                    Yes    Credit Card        Express              Yes
# 1                    Yes  Bank Transfer        Express              Yes
# 2                    Yes           Cash  Free Shipping              Yes
# 3                    Yes         PayPal   Next Day Air              Yes
# 4                    Yes           Cash  Free Shipping              Yes
# ...                  ...            ...            ...              ...
# 3897                  No    Credit Card       Standard               No
# 3898                  No         PayPal        Express               No
# 3899                  No  Bank Transfer   Store Pickup               No
# 3900                 Yes         PayPal  Free Shipping              Yes
# 3901                  No         PayPal  Free Shipping              Yes
#
#       Previous Purchases Frequency of Purchases age_group  cluster  \
# 0                     14            Fortnightly     51-60        2
# 1                      2            Fortnightly      0-20        1
# 2                     23                 Weekly     41-50        1
# 3                     49                 Weekly     21-30        0
# 4                     31               Annually     41-50        2
# ...                  ...                    ...       ...      ...
# 3897                  24              Quarterly     41-50        2
# 3898                  24                 Weekly     41-50        1
# 3899                  33              Quarterly     51-60        0
# 3900                   5              Quarterly     21-30        1
# 3901                   5              Quarterly     31-40        2
#
#       Expected yearly purchase frequency
# 0                                     26
# 1                                     26
# 2                                     52
# 3                                     52
# 4                                      1
# ...                                  ...
# 3897                                   4
# 3898                                  52
# 3899                                   4
# 3900                                   4
# 3901                                   4
#
# [3902 rows x 18 columns]
